# %%
# !pip install mplstereonet
# Out:
# Collecting mplstereonet
#   Downloading mplstereonet-0.6.2-py3-none-any.whl (31 kB)
# Requirement already satisfied: matplotlib>=1.1 in /Users/andy/.pyenv/versions/3.10.3/lib/python3.10/site-packages (from mplstereonet) (3.5.1)
# Requirement already satisfied: numpy>=1.1 in /Users/andy/.pyenv/versions/3.10.3/lib/python3.10/site-packages (from mplstereonet) (1.22.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/andy/.pyenv/versions/3.10.3/lib/python3.10/site-packages (from matplotlib>=1.1->mplstereonet) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/andy/.pyenv/versions/3.10.3/lib/python3.10/site-packages (from matplotlib>=1.1->mplstereonet) (4.31.2)
# Requirement already satisfied: cycler>=0.10 in /Users/andy/.pyenv/versions/3.10.3/lib/python3.10/site-packages (from matplotlib>=1.1->mplstereonet) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/andy/.pyenv/versions/3.10.3/lib/python3.10/site-packages (from matplotlib>=1.1->mplstereonet) (9.1.0)
# Requirement already satisfied: packaging>=20.0 in /Users/andy/.pyenv/versions/3.10.3/lib/python3.10/site-packages (from matplotlib>=1.1->mplstereonet) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/andy/.pyenv/versions/3.10.3/lib/python3.10/site-packages (from matplotlib>=1.1->mplstereonet) (3.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/andy/.pyenv/versions/3.10.3/lib/python3.10/site-packages (from matplotlib>=1.1->mplstereonet) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/andy/.pyenv/versions/3.10.3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=1.1->mplstereonet) (1.16.0)
# Installing collected packages: mplstereonet
# Successfully installed mplstereonet-0.6.2

# %%
import matplotlib.pyplot as plt
import mplstereonet

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='stereonet')

# Measurements follow the right-hand-rule to indicate dip direction
strike, dip = [315,320], [30,40]

ax.plane(strike, dip, 'g-', linewidth=2)
ax.pole(strike, dip, 'go', markersize=5)

ax.grid()

plt.show()
