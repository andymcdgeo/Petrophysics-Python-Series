# %% [markdown]
# # 17 - Working with DLIS Files Using DLISIO

# %% [markdown]
# ### Andy McDonald
# **Link to Article:**
#
# Click on the button below to run this notebook on binder without needing to download it or install any libraries.
# Please note that the interactive widgets will not work on Binder or when viewing the notebook on GitHub.
# **Binder:**
#
# ## Introduction
# There are a number of different formats that well log and petrophysical data can be stored in. In the earlier articles and notebooks of this series, we have mainly focused on loading data from CSV files ([here](https://github.com/andymcdgeo/Petrophysics-Python-Series/blob/master/01%20-%20Loading%20and%20Displaying%20Well%20Data%20From%20CSV.ipynb)) and LAS files ([here](https://towardsdatascience.com/loading-multiple-well-log-las-files-using-python-39ac35de99dd) and [here](https://andymcdonaldgeo.medium.com/loading-and-displaying-well-log-data-b9568efd1d8)). Even though LAS files are one of the common formats, they have a flat structure with a header section containing meta data about the well and the file followed by a series of columns containing values for each logging curve. As they are flat, they can't easily store array data. It is possible, but they individual elements of the array are split out into individual columns/curves within a LAS file as opposed to a single array. This is where DLIS files come in.
#
# Within this article, we will cover:
# - the basics of loading a DLIS file
# - exploring the contents and parameters within a DLIS file
# - displaying processed acoustic waveform data
#
# We will not be covering acoustic waveform processing. Just the display of previously processed data.
#
# This article was inspired by the work of Erlend M. Viggen (https://erlend-viggen.no/dlis-files/) who has created an excellent Jupyter Notebook which goes into more detail about working with DLIS files.
#
# ### DLIS Files
# Digital Log Interchange Standard (DLIS) files are structured binary files that contain data tables for well information and well logging data. The file format was developed in the late 1980's by Schlumberger and subsequently published in 1991 by the American Petroleum Institute to create a standardised well log data format. Full details of the standard format can be found [here.](http://w3.energistics.org/rp66/v1/Toc/main.html). The DLIS file format can often be difficult and awkward to work with at times due to the format being developed nearly 30 years ago, and different software packages and vendors can create their own flavours of DLIS by adding in new structures and object-types.
#
# DLIS files contain large amounts of metadata associated with the well and data. These sections do not contain the well data, these are stored within Frames, of which there can be many representing different logging passes/runs or processing stages (e.g. Raw or Interpreted).  Frames are table objects which contain the well log data, where each column represents a logging curve, and that data is indexed by time or depth. Each logging curve within the frame is referred to as a channel. The channels can be a single dimension or multi-dimensional
#
# ### dlisio
# dlsio is a python library that has been developed by Equinor ASA to read DLIS files and Log Information Standard79 (LIS79) files. Details of the library can be found [here](https://dlisio.readthedocs.io/en/stable/index.html).
#
# ### Data
# The data used within this article was sourced from the [NLOG: Dutch Oil and Gas Portal](https://www.nlog.nl/en/welcome-nlog).
#
# **Privacy Notice:** DLIS files can contain information that can identify individuals that were involved in the logging operations. To protect their identity from appearing in search engine results without their excplicit consent, these fields have been hidden in this article/notebook.

# %% [markdown]
# ## Library Imports
# The first step with any project is to load in the libraries that we want to use. For this notebook we will be using [NumPy](https://numpy.org) for working with arrays, [pandas](https://pandas.pydata.org) for storing data, and [matplotlib](https://matplotlib.org) for displaying the data. To load the data, we will be using the [dlisio](https://github.com/equinor/dlisio) library.
#
# Also, as we will be working with dataframes to view parameters, which can be numerous, we need to change the maximum number of rows that will be displayed when that dataframe is called. This is achieved by `pd.set_option('display.max_rows', 500)`.

# %%
from dlisio import dlis
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option('display.max_rows', 500)

# %%
import dlisio
dlisio.__version__
# Out:
# '0.3.1'

# %% [markdown]
# ## Loading a DLIS File

# %% [markdown]
# As we are working with a single DLIS file, we can use the following code to load the file. A physical DLIS file can contain multiple logical files, therefore, using this syntax allows the first file to be output to `f` and any subsequent logical files placed into `tail`.

# %%
f, *tail = dlis.load('Data/NLOG_LIS_LAS_7857_FMS_DSI_MAIN_LOG.DLIS')

# %% [markdown]
# We can see the contents of each of these by calling upon their names. If we call upon `f`, we can see that it returns a `LogicalFile(00001_AC_WORK` and if we call upon `tail`, we get a blank list, which lets us know that there are no other logical files within the DLIS.

# %%
print(f)
print(tail)
# Out:
# LogicalFile(FMS_DSI_138PUP)
# []

# %% [markdown]
# To view the high level contents of the file we can use the `.describe()` method. This returns information about the number of frames, channels and objects within the Logical File. When we apply this to `f` we can see we have a file with 4 frames and 484 channels (logging curves), in addition to a number of known and unknown objects.

# %%
f.describe()
# Out:
# ------------
# Logical File
# ------------
# Description : LogicalFile(FMS_DSI_138PUP)
# Frames      : 4
# Channels    : 484
#
# Known objects
# --
# FILE-HEADER             : 1
# ORIGIN                  : 1
# AXIS                    : 50
# EQUIPMENT               : 27
# TOOL                    : 5
# PARAMETER               : 480
# CALIBRATION-MEASUREMENT : 22
# CALIBRATION-COEFFICIENT : 12
# CALIBRATION             : 341
# PROCESS                 : 3
# CHANNEL                 : 484
# FRAME                   : 4
#
# Unknown objects
# --
# 440-CHANNEL                  : 538
# 440-PRESENTATION-DESCRIPTION : 1
# 440-OP-CHANNEL               : 573

# %% [markdown]
# ## Viewing the File's Metadata

# %% [markdown]
# ### Data Origin
#
# The first set of metadata we will look at is the origin. This provides information about the source of the data within the file. Occassionally, data may originate from multiple sources so we need to account for this by unpacking the origins into two variables. We can always check if there is other origin information by printing the length of the list.

# %%
origin, *origin_tail = f.origins
print(len(origin_tail))
# Out:
# 0

# %% [markdown]
# For this article, we will focus on `origin`. We can view the details of it, by calling upon `describe()`. This provides details about the field, well, and other file information.

# %%
origin.describe()
# Out:
# ------
# Origin
# ------
# name   : DLIS_DEFINING_ORIGIN
# origin : 41
# copy   : 0
#
# Logical file ID          : FMS_DSI_138PUP
# File set name and number : WINTERSHALL/L5-9 / 41
# File number and type     : 170 / PLAYBACK
#
# Field                   : L5
# Well (id/name)          :  / L5-9
# Produced by (code/name) : 440 / Schlumberger
# Produced for            : Wintershall Noordzee B.V.
# Run number              : -1
# Descent number          : -1
# Created                 : 2002-02-17 18:18:52
#
# Created by              : OP, (version: 9C2-303)
# Other programs/services : MESTB: Micro Electrical Scanner - B (Slim)  SGTL:
#                           Scintillation Gamma-Ray - L           DTAA: Downhole
#                           Toolbus Adapter - A          DSSTB: Dipole Shear
#                           Imager - B              DTCA: DTS Telemetry Cartridge
#                           ACTS: Auxiliary Compression Tension Sub - B DIP: Dip
#                           Computation                        DIR: Directional
#                           Survey Computation         HOLEV: Integrated
#                           Hole/Cement Volume

# %% [markdown]
# ### Frames

# %% [markdown]
# Frames within a DLIS file can represent different logging passes or different stages of data, such as raw well log measurements to pertophysical interpretations or processed data. Each frame has a number of properties. The example code below prints out the properties in an easy-to-read format.

# %%
for frame in f.frames:
    
    # Search through the channels for the index and obtain the units
    for channel in frame.channels:
        if channel.name == frame.index:
            depth_units = channel.units
    
    print(f'Frame Name: \t\t {frame.name}')
    print(f'Index Type: \t\t {frame.index_type}')
    print(f'Depth Interval: \t {frame.index_min} - {frame.index_max} {depth_units}')
    print(f'Depth Spacing: \t\t {frame.spacing} {depth_units}')
    print(f'Direction: \t\t {frame.direction}')
    print(f'Num of Channels: \t {len(frame.channels)}')
    print(f'Channel Names: \t\t {str(frame.channels)}')
    print('\n\n')
# Out:
# Frame Name: 		 60B
# Index Type: 		 BOREHOLE-DEPTH
# Depth Interval: 	 0 - 0 0.1 in
# Depth Spacing: 		 -60 0.1 in
# Direction: 		 DECREASING
# Num of Channels: 	 77
# Channel Names: 		 [Channel(TDEP), Channel(BS), Channel(CS), Channel(TENS), Channel(ETIM), Channel(DEVI), Channel(P1AZ_MEST), Channel(ANOR), Channel(FINC), Channel(HAZI), Channel(P1AZ), Channel(RB), Channel(SDEV), Channel(GAT), Channel(GMT), Channel(ECGR), Channel(ITT), Channel(SPHI), Channel(DCI2), Channel(DCI4), Channel(SOBS), Channel(DTCO), Channel(DTSM), Channel(PR), Channel(VPVS), Channel(CHR2), Channel(DT2R), Channel(DTRP), Channel(CHRP), Channel(DTRS), Channel(CHRS), Channel(DTTP), Channel(CHTP), Channel(DTTS), Channel(CHTS), Channel(DT2), Channel(DT4P), Channel(DT4S), Channel(SPCF), Channel(DPTR), Channel(DPAZ), Channel(QUAF), Channel(DDIP), Channel(DDA), Channel(FCD), Channel(HDAR), Channel(RGR), Channel(TIME), Channel(CVEL), Channel(MSW1), Channel(MSW2), Channel(FNOR), Channel(SAS2), Channel(SAS4), Channel(PWF2), Channel(PWN2), Channel(PWF4), Channel(PWN4), Channel(SVEL), Channel(SSVE), Channel(SPR2), Channel(SPR4), Channel(SPT4), Channel(DF), Channel(CDF), Channel(CLOS), Channel(ED), Channel(ND), Channel(TVDE), Channel(VSEC), Channel(CWEL), Channel(AREA), Channel(AFCD), Channel(ABS), Channel(IHV), Channel(ICV), Channel(GR)]
#
#
#
# Frame Name: 		 10B
# Index Type: 		 BOREHOLE-DEPTH
# Depth Interval: 	 0 - 0 0.1 in
# Depth Spacing: 		 -10 0.1 in
# Direction: 		 DECREASING
# Num of Channels: 	 4
# Channel Names: 		 [Channel(TDEP), Channel(IDWD), Channel(TIME), Channel(SCD)]
#
#
#
# Frame Name: 		 1B
# Index Type: 		 BOREHOLE-DEPTH
# Depth Interval: 	 0 - 0 0.1 in
# Depth Spacing: 		 -1 0.1 in
# Direction: 		 DECREASING
# Num of Channels: 	 84
# Channel Names: 		 [Channel(TDEP), Channel(TIME), Channel(EV), Channel(BA28), Channel(BA17), Channel(BB17), Channel(BC13), Channel(BD13), Channel(BB28), Channel(BA13), Channel(BB13), Channel(BC17), Channel(BD17), Channel(BA22), Channel(BA23), Channel(BA24), Channel(BC28), Channel(BA25), Channel(BA26), Channel(BA27), Channel(BA11), Channel(BA12), Channel(BA14), Channel(BA15), Channel(BA16), Channel(BA18), Channel(BA21), Channel(BC11), Channel(BC12), Channel(BC14), Channel(BC15), Channel(BC16), Channel(BC18), Channel(BC21), Channel(BC22), Channel(BC23), Channel(BC24), Channel(BC25), Channel(BC26), Channel(BC27), Channel(BB22), Channel(BB23), Channel(BB24), Channel(BD28), Channel(BB25), Channel(BB26), Channel(BB27), Channel(BB11), Channel(BB12), Channel(BB14), Channel(BB15), Channel(BB16), Channel(BB18), Channel(BB21), Channel(BD11), Channel(BD12), Channel(BD14), Channel(BD15), Channel(BD16), Channel(BD18), Channel(BD21), Channel(BD22), Channel(BD23), Channel(BD24), Channel(BD25), Channel(BD26), Channel(BD27), Channel(SB1), Channel(DB1), Channel(DB2), Channel(DB3A), Channel(DB4A), Channel(SB2), Channel(DB1A), Channel(DB2A), Channel(DB3), Channel(DB4), Channel(FCAX), Channel(FCAY), Channel(FCAZ), Channel(FTIM), Channel(AZSNG), Channel(AZS1G), Channel(AZS2G)]
#
#
#
# Frame Name: 		 15B
# Index Type: 		 BOREHOLE-DEPTH
# Depth Interval: 	 0 - 0 0.1 in
# Depth Spacing: 		 -15 0.1 in
# Direction: 		 DECREASING
# Num of Channels: 	 12
# Channel Names: 		 [Channel(TDEP), Channel(TIME), Channel(C1), Channel(C2), Channel(U-MBAV), Channel(AX), Channel(AY), Channel(AZ), Channel(EI), Channel(FX), Channel(FY), Channel(FZ)]

# %% [markdown]
# This returns the following summary. Which indicates that two frames exist within this file. With the first frame containing basic well log curves of bitsize (BIT), caliper (CAL), gamma ray (GR) and tension (TEN). The second frame contains the post-processed acoustic waveform data.

# %% [markdown]
# ### Parameters within the DLIS File
# As seen earlier, we have a number of objects associated with the DLIS file. To make them easier to read we can create a short function that creates a pandas dataframe containing the parameters.

# %%
def summary_dataframe(object, **kwargs):
    # Create an empty dataframe
    df = pd.DataFrame()
    
    # Iterate over each of the keyword arguments
    for i, (key, value) in enumerate(kwargs.items()):
        list_of_values = []
        
        # Iterate over each parameter and get the relevant key
        for item in object:
            # Account for any missing values.
            try:
                x = getattr(item, key)
                list_of_values.append(x)
            except:
                list_of_values.append('')
                continue
        
        # Add a new column to our data frame
        df[value]=list_of_values
    
    # Sort the dataframe by column 1 and return it
    return df.sort_values(df.columns[0])

# %% [markdown]
# The parameters can be accessed by calling upon `f.parameters`. To access the parameters, we can use the attributes `name`, `long_name` and `values` and pass these into the summary function.
#
# This returns a long table of each of the parameters. The example below is a small section of that table. From it, we can see parameters such as bottom log interval, borehole salinity and bottom hole temperature.

# %%
param_df = summary_dataframe(f.parameters, name='Name', long_name='Long Name', values='Value')

# Hiding people's names that may be in parameters.
# These two lines can be commented out to show them
mask = param_df['Name'].isin(['R8', 'RR1', 'WITN', 'ENGI'])
param_df = param_df[~mask]

param_df
# Out:
#                Name                                          Long Name  \
# 48             ACCC                         Accelerometer coefficients
# 53             ACCM                 Accelerometer Month of Calibration
# 58             ACCN                        Accelerometer Serial Number
# 51             ACCT             Accelerometer Type (Manufacturer Code)
# 56             ACCY                  Accelerometer Year of Calibration
# 60             ACPP                        Accelerometer PROM Presence
# 72             AFMO                       Accelerometer Filtering Mode
# 0         ALTDPCHAN                    Name of alternate depth channel
# 317             AMD                       Azimuth of Maximum Deviation
# 369             APD                              Above Permanent Datum
# 436            APIN                                  API Serial Number
# 62              ART                Accelerometer Reference Temperature
# 55             ATIM                            Time of acc calibration
# 466       BARS_MTR1      Length for Monopole Transmitter to Receiver 1
# 325              BG                    Gas Formation Volume Factor, Bg
# 81              BHS                                    Borehole Status
# 85              BHT     Bottom Hole Temperature (used in calculations)
# 278            BILI                Bond Index Level for Zone Isolation
# 365             BLI                                Bottom Log Interval
# 327              BO                    Oil Formation Volume Factor, Bo
# 323             BPP                              Bubble Point Pressure
# 322             BPT                           Bubble Point Temperature
# 355              BS                                           Bit Size
# 336            BSAL                                  Borehole Salinity
# 364            BSDF                                Bit Size Depth From
# 363            BSDT                                  Bit Size Depth To
# 326              BW                  Water Formation Volume Factor, Bw
# 385            CADD                                   Cement Additives
# 361            CADT                                    Casing Depth To
# 96             CASF               Label Casing Function - Monopole P&S
# 421            CASG                                       Casing Grade
# 388            CASN                               Casing String Number
# 360            CBDR                           Casing Bottom of Driller
# 359            CBLO                            Casing Bottom of Logger
# 315              CD                                  Casing Shoe Depth
# 334            CDEN                                     Cement Density
# 362             CDF                                  Casing Depth From
# 287            CDTS                                    C-Delta-T Shale
# 387             CJT                                    Cement Job Type
# 452            CLAB                                   County/Rig Label
# 448              CN                                       Company Name
# 447             CN1                                Company Name Line 1
# 275            COLL  Label Slowness Lower Limit - Monopole P&S Comp...
# 429            CONT                                          Continent
# 6            CONTYP                                    Conveyance Type
# 274            COUL  Label Slowness Upper Limit - Monopole P&S Comp...
# 444            COUN                                 County or Rig Name
# 297            CSBL                           CSB DIP Number of Levels
# 354            CSIZ                                Current Casing Size
# 280            CSTR                     Compressive Strength of Cement
# 357            CTOP                               Estimated Cement Top
# 353            CWEI                                      Casing Weight
# 333            CWLO                                  Cement Water Loss
# 428            DATE                             Date as Month-Day-Year
# 139            DCL1                  STC DC Lower Limit - Lower Dipole
# 138            DCL2                  STC DC Lower Limit - Upper Dipole
# 137            DCL3             STC DC Lower Limit - Monopole Stoneley
# 136            DCL4                  STC DC Lower Limit - Monopole P&S
# 123            DCM1                      STC DC Moveout - Lower Dipole
# 122            DCM2                      STC DC Moveout - Upper Dipole
# 121            DCM3                 STC DC Moveout - Monopole Stoneley
# 120            DCM4                      STC DC Moveout - Monopole P&S
# 419             DCS                           Date Circulation Stopped
# 135            DCU1                  STC DC Upper Limit - Lower Dipole
# 134            DCU2                  STC DC Upper Limit - Upper Dipole
# 133            DCU3             STC DC Upper Limit - Monopole Stoneley
# 132            DCU4                  STC DC Upper Limit - Monopole P&S
# 244            DDE1                                 Digitizing Delay 1
# 236            DDE2                                 Digitizing Delay 2
# 228            DDE3                                 Digitizing Delay 3
# 220            DDE4                                 Digitizing Delay 4
# 212            DDE5                                 Digitizing Delay 5
# 254            DDEX                                 Digitizing Delay X
# 289            DDLG             Digital Telemetry Module Downlink Gain
# 288            DDLS            Digital Telemetry Module Downlink Shape
# 28          DEPREM1                                     Depth Remark 1
# 27          DEPREM2                                     Depth Remark 2
# 26          DEPREM3                                     Depth Remark 3
# 25          DEPREM4                                     Depth Remark 4
# 24          DEPREM5                                     Depth Remark 5
# 23          DEPREM6                                     Depth Remark 6
# 352             DFD                             Drilling Fluid Density
# 350             DFL                                Drilling Fluid Loss
# 349            DFPH                                  Drilling Fluid PH
# 420             DFT                                Drilling Fluid Type
# 351             DFV                           Drilling Fluid Viscosity
# 36             DIFF                 Maximum Permitted Depth Difference
# 426            DLAB                              Date Logger At Bottom
# 114            DLCS          Label Compressional Source - Dipole Shear
# 115            DLHS        Label Hole Diameter Source for SOBS Channel
# 437             DMF                             Drilling Measured From
# 457              DO                          Depth Offset for Playback
# 300            DPAD                                       Disabled Pad
# 76             DPPM                   Density Porosity Processing Mode
# 271            DSHL          Label Slowness Lower Limit - Dipole Shear
# 270            DSHU          Label Slowness Upper Limit - Dipole Shear
# 245            DSI1                        Digitizer Sample Interval 1
# 237            DSI2                        Digitizer Sample Interval 2
# 229            DSI3                        Digitizer Sample Interval 3
# 221            DSI4                        Digitizer Sample Interval 4
# 213            DSI5                        Digitizer Sample Interval 5
# 255            DSIX                        Digitizer Sample Interval X
# 113            DTCS      Compressional Delta-T Source for DTCO Channel
# 286             DTF                                      Delta-T Fluid
# 285             DTM                                     Delta-T Matrix
# 112            DTSS              Shear Delta-T Source for DTSM Channel
# 290            DULG            Digital Telemetry Cartridge Uplink Gain
# 292            DULM            Digital Telemetry Cartridge Uplink Mode
# 291            DULR            Digital Telemetry Cartridge Uplink Rate
# 243            DWC1                             Digitizer Word Count 1
# 235            DWC2                             Digitizer Word Count 2
# 227            DWC3                             Digitizer Word Count 3
# 219            DWC4                             Digitizer Word Count 4
# 211            DWC5                             Digitizer Word Count 5
# 253            DWCX                             Digitizer Word Count X
# 372             EDF                         Elevation of Derrick Floor
# 373             EGL                          Elevation of Ground Level
# 374             EKB                         Elevation of Kelly Bushing
# 296            ELRA                                  Electrical Radius
# 371             ELZ                              Elevation of Log Zero
# 463            ENVI                            Acquisition Environment
# 370             EPD                       Elevation of Permanent Datum
# 41             ERDS                           EMEX Regulation Data Set
# 314             FCD                     Future Casing (Outer) Diameter
# 284             FCF                      CBL Fluid Compensation Factor
# 205            FGM5                        First Motion Gate Moveout 5
# 98             FILG              Label Fill Gap Control - Monopole P&S
# 442              FL                                     Field Location
# 441             FL1                              Field Location Line 1
# 440             FL2                              Field Location Line 2
# 358            FLEV                                        Fluid Level
# 455        FLSHSTRM       Flush depth-delayed streams to output at end
# 206            FMG5                        First Motion Minimum Gate 5
# 91             FMLL                         Slowness Lower Limit - FMD
# 89             FMRC                              Restart Control - FMD
# 207            FMT5                           First Motion Threshold 5
# 90             FMUL                         Slowness Upper Limit - FMD
# 445              FN                                         Field Name
# 259             FPM                              Processing Mode - FMD
# 465            FULT               FTB Uplink Throughput for Sonic Tool
# 84             GCSE                      Generalized Caliper Selection
# 78             GDEV  Average Angular Deviation of Borehole from Normal
# 240            GDT1                                     Gain Delta-T 1
# 232            GDT2                                     Gain Delta-T 2
# 224            GDT3                                     Gain Delta-T 3
# 216            GDT4                                     Gain Delta-T 4
# 208            GDT5                                     Gain Delta-T 5
# 250            GDTX                                     Gain Delta-T X
# 328            GGRA                                        Gas Gravity
# 77             GGRD                                Geothermal Gradient
# 241            GIN1                                    Gain Interval 1
# 233            GIN2                                    Gain Interval 2
# 225            GIN3                                    Gain Interval 3
# 217            GIN4                                    Gain Interval 4
# 209            GIN5                                    Gain Interval 5
# 251            GINX                                    Gain Interval X
# 64              GLM                                  GPIT Logging Mode
# 279            GOBO                                          Good Bond
# 82             GRSE              Generalized Mud Resistivity Selection
# 63              GTM                                GPIT Telemetry Mode
# 79             GTSE                  Generalized Temperature Selection
# 390            HID1                           Header Identifier Line 1
# 391            HID2                           Header Identifier Line 2
# 389            HIDE                                  Header Identifier
# 392             HLD                            Header Legal Disclaimer
# 312            HVCS           Integrated Hole Volume Caliper Selection
# 324             IBG                1/Gas Formation Volume Factor, 1/Bg
# 71             ICMO                      Inclinometry Computation Mode
# 33            IDWCD                 IDW Calibration Date (dd-MMM-yyyy)
# 19           IDWCSN                       IDW Calibrator Serial Number
# 8            IDWLCN                         IDW Calibration Cable Type
# 22            IDWSN                                  IDW Serial Number
# 34           IDWTYP                                           IDW Type
# 21           IDWWC1                            IDW Wheel Corrrection 1
# 20           IDWWC2                            IDW Wheel Corrrection 2
# 313            IHVC                     Integrated Hole Volume Control
# 379            ILL1                        Instrumentation Logo Line 1
# 378            ILL2                        Instrumentation Logo Line 2
# 302             INT                               Correlation Interval
# 75           ISSBAR                               SGT Nuclear Mud Type
# 283            ITTS                     Integrated Transit Time Source
# 37             JETA                               Job Events Auto Save
# 258            JNUM                                SPAC DHC ROM Number
# 70             LATD                                Latitude (N=+ S=- )
# 435            LATI                                           Latitude
# 376             LCC                               Logging Company Code
# 460             LCL                               Logging Cable Length
# 386            LCMT                                   Lead Cement Type
# 461             LCN                          Logging Cable Name (Type)
# 16             LCSN                        Logging Cable Serial Number
# 335            LCVO                                 Lead Cement Volume
# 97              LFC           Label Formation Character - Monopole P&S
# 451            LLAB                                      Section Label
# 438             LMF                                  Log Measured From
# 454         LOGMODE                                 Depth Logging Mode
# 5            LOGSEQ                                       Log Sequence
# 69             LOND                                Longitude (E=+ W=-)
# 434            LONG                                          Longitude
# 263            LPM1               Label Processing Mode - Lower Dipole
# 262            LPM2               Label Processing Mode - Upper Dipole
# 261            LPM3          Label Processing Mode - Monopole Stoneley
# 260            LPM4               Label Processing Mode - Monopole P&S
# 477            LTXG                  Lower Dipole Transmitter Geometry
# 424             LUL                              Logging Unit Location
# 377             LUN                                Logging Unit Number
# 52             MAGM                  Magnetometer Month of Calibration
# 57             MAGN                         Magnetometer Serial Number
# 50             MAGT              Magnetometer Type (Manufacturer Code)
# 54             MAGY                   Magnetometer Year of Calibration
# 92             MAI5                  Slowness Averaging Interval - FMD
# 59             MAPP                         Magnetometer PROM Presence
# 83             MATR       Rock Matrix for Neutron Porosity Corrections
# 276             MCI                          Minimum Cemented Interval
# 111             MCS                               Mean Casing Slowness
# 415            MCSS                             Mud Cake Sample Source
# 343            MCST                        Mud Cake Sample Temperature
# 68             MDEC                         Magnetic Field Declination
# 88             MDS5                    Multishot Delta-T Scatter - FMD
# 67             MFIN                           Magnetic Field Intensity
# 416            MFSS                         Mud Filtrate Sample Source
# 345            MFST                    Mud Filtrate Sample Temperature
# 47             MGMC                          Magnetometer coefficients
# 356             MHD                             Maximum Hole Deviation
# 66             MINC                         Magnetic Field Inclination
# 46              MLM                                  MEST Logging Mode
# 2              MMDU                          Magnetic Mark Depth Units
# 337             MRT                       Maximum Recorded Temperature
# 340            MRT1                     Maximum Recorded Temperature 1
# 339            MRT2                     Maximum Recorded Temperature 2
# 338            MRT3                     Maximum Recorded Temperature 3
# 61             MRTE                      Magneto Reference Temperature
# 277             MSA                            Minimum Sonic Amplitude
# 417             MSS                                  Mud Sample Source
# 347             MST                             Mud Sample Temperature
# 49             MTIM                   Time of magnetometer calibration
# 475            MTXG                      Monopole Transmitter Geometry
# 430            NATI                                             Nation
# 316             NLS                              Nominal Logging Speed
# 242            NWS1                         Number Waveforms Stacked 1
# 234            NWS2                         Number Waveforms Stacked 2
# 226            NWS3                         Number Waveforms Stacked 3
# 218            NWS4                         Number Waveforms Stacked 4
# 210            NWS5                         Number Waveforms Stacked 5
# 252            NWSX                         Number Waveforms Stacked X
# 329            ODEN                                        Oil Density
# 375            OPER                                    Operator's Code
# 414             OS1                              Other Services Line 1
# 413             OS2                              Other Services Line 2
# 412             OS3                              Other Services Line 3
# 411             OS4                              Other Services Line 4
# 410             OS5                              Other Services Line 5
# 65             PADT              Presentation Allow Disallow Threshold
# 456         PBVSADP           Use alternate depth channel for playback
# 439            PDAT                                    Permanent Datum
# 458              PP                                Playback Processing
# 38             PTYP  Pad Type - High Resolution or Medium Extended ...
# 380            PVER                                    Program Version
# 409              R1                                      Remark Line 1
# 400             R10                                     Remark Line 10
# 399             R11                                     Remark Line 11
# 398             R12                                     Remark Line 12
# 397             R13                                     Remark Line 13
# 396             R14                                     Remark Line 14
# 395             R15                                     Remark Line 15
# 394             R16                                     Remark Line 16
# 393             R17                                     Remark Line 17
# 408              R2                                      Remark Line 2
# 407              R3                                      Remark Line 3
# 406              R4                                      Remark Line 4
# 405              R5                                      Remark Line 5
# 404              R6                                      Remark Line 6
# 403              R7                                      Remark Line 7
# 401              R9                                      Remark Line 9
# 431            RANG                                              Range
# 257            RATE                                        Firing Rate
# 42              RBS                       Resistivity Button Selection
# 4            RIGTYP                                           Rig Type
# 449            RLAB                                        Range Label
# 31             RLDT                   Reference Log Date (dd-MMM-yyyy)
# 30             RLNM                                 Reference Log Name
# 29             RLRN                           Reference Log Run Number
# 342             RMB                           Resistivity of Mud - BHT
# 344            RMCS                     Resistivity of Mud Cake Sample
# 341            RMFB                  Resistivity of Mud Filtrate - BHT
# 346            RMFS                 Resistivity of Mud Filtrate Sample
# 348             RMS                          Resistivity of Mud Sample
# 95             RSMN  Label Shear/Compressional Minimum Ratio - Mono...
# 94             RSMX  Label Shear/Compressional Maximum Ratio - Mono...
# 10             RULB                            Rig Up Length at Bottom
# 11             RULS                           Rig Up Length at Surface
# 427             RUN                                         Run Number
# 320              RW                       Resistivity of Connate Water
# 474            RX1G                                Receiver 1 Geometry
# 473            RX2G                                Receiver 2 Geometry
# 472            RX3G                                Receiver 3 Geometry
# 471            RX4G                                Receiver 4 Geometry
# 470            RX5G                                Receiver 5 Geometry
# 469            RX6G                                Receiver 6 Geometry
# 468            RX7G                                Receiver 7 Geometry
# 467            RX8G                                Receiver 8 Geometry
# 246            SAM1  DSST Sonic Acquisition Mode 1 - Lower Dipole Mode
# 238            SAM2  DSST Sonic Acquisition Mode 2 - Upper Dipole Mode
# 230            SAM3  DSST Sonic Acquisition Mode 3 - Low Frequency ...
# 222            SAM4  DSST Sonic Acquisition Mode 4 - High Frequency...
# 214            SAM5  DSST Sonic Acquisition Mode 5 - High Frequency...
# 256            SAMX  DSST Sonic Acquisition Mode X - Both Dipoles o...
# 303            SANG                           Correlation Search Angle
# 171            SAS1              STC Sonic Array Status - Lower Dipole
# 170            SAS2              STC Sonic Array Status - Upper Dipole
# 169            SAS3         STC Sonic Array Status - Monopole Stoneley
# 168            SAS4              STC Sonic Array Status - Monopole P&S
# 93             SAS5                           Sonic Array Status - FMD
# 180            SBO1              STC Search Band Offset - Lower Dipole
# 179            SBO2              STC Search Band Offset - Upper Dipole
# 178            SBO3         STC Search Band Offset - Monopole Stoneley
# 177            SBO4              STC Search Band Offset - Monopole P&S
# 172            SBR4                STC Baseline Removal - Monopole P&S
# 298            SBUT                                 DIP Set of Buttons
# 184            SBW1                STC Search Bandwidth - Lower Dipole
# 183            SBW2                STC Search Bandwidth - Upper Dipole
# 182            SBW3           STC Search Bandwidth - Monopole Stoneley
# 181            SBW4                STC Search Bandwidth - Monopole P&S
# 1         SCD_ACCEL        Accelerometer driving Speed Corrected Depth
# 13            SCORR                                 Stretch Correction
# 295            SDFA                       Side-by-Side Distance Factor
# 433            SECT                                            Section
# 200            SFC1             STC Formation Character - Lower Dipole
# 199            SFC2             STC Formation Character - Upper Dipole
# 198            SFC3        STC Formation Character - Monopole Stoneley
# 197            SFC4             STC Formation Character - Monopole P&S
# 176            SFM1                          STC Filter - Lower Dipole
# 175            SFM2                          STC Filter - Upper Dipole
# 174            SFM3                     STC Filter - Monopole Stoneley
# 173            SFM4                          STC Filter - Monopole P&S
# 131            SGL1              STC Signal Lower Limit - Lower Dipole
# 130            SGL2              STC Signal Lower Limit - Upper Dipole
# 129            SGL3         STC Signal Lower Limit - Monopole Stoneley
# 128            SGL4              STC Signal Lower Limit - Monopole P&S
# 119            SGM1                  STC Signal Moveout - Lower Dipole
# 118            SGM2                  STC Signal Moveout - Upper Dipole
# 117            SGM3             STC Signal Moveout - Monopole Stoneley
# 116            SGM4                  STC Signal Moveout - Monopole P&S
# 321            SGOR                             Solution Gas Oil Ratio
# 127            SGU1              STC Signal Upper Limit - Lower Dipole
# 126            SGU2              STC Signal Upper Limit - Upper Dipole
# 125            SGU3         STC Signal Upper Limit - Monopole Stoneley
# 124            SGU4              STC Signal Upper Limit - Monopole P&S
# 273            SHLL    Label Slowness Lower Limit - Monopole P&S Shear
# 80              SHT                           Surface Hole Temperature
# 272            SHUL    Label Slowness Upper Limit - Monopole P&S Shear
# 462  SIMULATE_DELAY                         Simulate Acquisition Delay
# 453            SLAB                               State/Province Label
# 192            SLL1            STC Slowness Lower Limit - Lower Dipole
# 191            SLL2            STC Slowness Lower Limit - Upper Dipole
# 190            SLL3       STC Slowness Lower Limit - Monopole Stoneley
# 189            SLL4            STC Slowness Lower Limit - Monopole P&S
# 45             SOFF                                           Standoff
# 73             SOGR                              SGT Standoff Distance
# 381             SON                               Service Order Number
# 299            SPAN                                       DIP Spanning
# 309            SPED                   East Departure of Starting Point
# 459            SPEE                            Simulated Logging Speed
# 282            SPFS                             Sonic Porosity Formula
# 267            SPM1                 STC Processing Mode - Lower Dipole
# 266            SPM2                 STC Processing Mode - Upper Dipole
# 265            SPM3            STC Processing Mode - Monopole Stoneley
# 264            SPM4                 STC Processing Mode - Monopole P&S
# 310            SPND                  North Departure of Starting Point
# 281            SPSO                              Sonic Porosity Source
# 308            SPVD                              TVD of Starting Point
# 147            SST1                   STC Slowness Step - Lower Dipole
# 146            SST2                   STC Slowness Step - Upper Dipole
# 145            SST3              STC Slowness Step - Monopole Stoneley
# 144            SST4                   STC Slowness Step - Monopole P&S
# 203            SSW1                 STC Source Waveform - Lower Dipole
# 202            SSW2                 STC Source Waveform - Upper Dipole
# 201            SSW4                 STC Source Waveform - Monopole P&S
# 443            STAT                                  State or Province
# 293            STDA                             Structural DIP Azimuth
# 294            STDI                               Structural DIP Angle
# 12            STDLC                Subsequent Trip Down Log Correction
# 318            STEM                                Surface Temperature
# 301            STEP                                   Correlation Step
# 269            STLL     Label Slowness Lower Limit - Monopole Stoneley
# 268            STUL     Label Slowness Upper Limit - Monopole Stoneley
# 188            SUL1            STC Slowness Upper Limit - Lower Dipole
# 187            SUL2            STC Slowness Upper Limit - Upper Dipole
# 186            SUL3       STC Slowness Upper Limit - Monopole Stoneley
# 185            SUL4            STC Slowness Upper Limit - Monopole P&S
# 143            SWD1                  STC Slowness Width - Lower Dipole
# 142            SWD2                  STC Slowness Width - Upper Dipole
# 141            SWD3             STC Slowness Width - Monopole Stoneley
# 140            SWD4                  STC Slowness Width - Monopole P&S
# 311            TAZI                           Vertical Section Azimuth
# 196            TBF1          STC Time for Baseline Fill - Lower Dipole
# 195            TBF2          STC Time for Baseline Fill - Upper Dipole
# 194            TBF3     STC Time for Baseline Fill - Monopole Stoneley
# 193            TBF4          STC Time for Baseline Fill - Monopole P&S
# 383             TCA                              Tail Cement Additives
# 331            TCDE                                Tail Cement Density
# 418             TCS                           Time Circulation Stopped
# 384            TCTY                                   Tail Cement Type
# 332             TCV                                 Tail Cement Volume
# 330            TCWL                             Tail Cement Water Loss
# 3                TD                                        Total Depth
# 368             TDD                              Total Depth - Driller
# 367             TDL                               Total Depth - Logger
# 100            THSH               Label Spike Threshold - Dipole Shear
# 99             THST          Label Spike Threshold - Monopole Stoneley
# 306            TIED                     East Departure of Tie-in Point
# 304            TIMD                   Along-hole depth of Tie-in Point
# 307            TIND                    North Departure of Tie-in Point
# 305            TIVD                                TVD of Tie-in Point
# 425            TLAB                              Time Logger At Bottom
# 366             TLI                                   Top Log Interval
# 167            TLL1                STC Time Lower Limit - Lower Dipole
# 166            TLL2                STC Time Lower Limit - Upper Dipole
# 165            TLL3           STC Time Lower Limit - Monopole Stoneley
# 164            TLL4                STC Time Lower Limit - Monopole P&S
# 450           TLLAB                                     Township Label
# 86             TMRI      Telemetry Error Msg Report Interval (for SCP)
# 32            TNDCD      Tension Device Calibration Date (dd-MMM-yyyy)
# 18           TNDCSN            Tension Device Calibrator Serial Number
# 15            TNDGN                                Tension Device GAIN
# 14           TNDOFF                              Tension Device Offset
# 17            TNDSN                       Tension Device Serial Number
# 7            TNDTYP                                     Tension Device
# 432            TOWN                                           Township
# 74             TPOS                            SGT Centered/Eccentered
# 35             TREF                     Reference Tension of the Cable
# 87             TSRI      Telemetry Status Report Interval (for IO Mon)
# 155            TST1                       STC Time Step - Lower Dipole
# 154            TST2                       STC Time Step - Upper Dipole
# 153            TST3                  STC Time Step - Monopole Stoneley
# 152            TST4                       STC Time Step - Monopole P&S
# 163            TUL1                STC Time Upper Limit - Lower Dipole
# 162            TUL2                STC Time Upper Limit - Upper Dipole
# 161            TUL3           STC Time Upper Limit - Monopole Stoneley
# 160            TUL4                STC Time Upper Limit - Monopole P&S
# 151            TWD1                      STC Time Width - Lower Dipole
# 150            TWD2                      STC Time Width - Upper Dipole
# 149            TWD3                 STC Time Width - Monopole Stoneley
# 148            TWD4                      STC Time Width - Monopole P&S
# 159            TWI1         STC Integration Time Window - Lower Dipole
# 158            TWI2         STC Integration Time Window - Upper Dipole
# 157            TWI3    STC Integration Time Window - Monopole Stoneley
# 156            TWI4         STC Integration Time Window - Monopole P&S
# 249            TWRX                 Transmitter Waveform Sample Rate X
# 319             TWS                Temperature of Connate Water Sample
# 248            TWSX                      Transmitter Waveform Select X
# 464          U-MAEP                         MEST Automatic EMEX Policy
# 476            UTXG                  Upper Dipole Transmitter Geometry
# 382            UWID                  Unique Well Identification Number
# 479            VCEM                            Cumulated Cement Volume
# 478            VHOL                              Cumulated Hole Volume
# 102            WASH            Label Early Arrival Cost - Dipole Shear
# 101            WAST       Label Early Arrival Cost - Monopole Stoneley
# 110            WCSH                Label Coherence Cost - Dipole Shear
# 109            WCST           Label Coherence Cost - Monopole Stoneley
# 104            WDSH            Label S/T Deviation Cost - Dipole Shear
# 103            WDST       Label S/T Deviation Cost - Monopole Stoneley
# 239            WFM1                                    Waveform Mode 1
# 231            WFM2                                    Waveform Mode 2
# 223            WFM3                                    Waveform Mode 3
# 215            WFM4                                    Waveform Mode 4
# 204            WFM5                                    Waveform Mode 5
# 247            WFMX                                    Waveform Mode X
# 446              WN                                          Well Name
# 108            WSSH                 Label Slowness Cost - Dipole Shear
# 107            WSST            Label Slowness Cost - Monopole Stoneley
# 106            WTSH                     Label Time Cost - Dipole Shear
# 105            WTST                Label Time Cost - Monopole Stoneley
# 44             XGAI                                               Gain
# 40             XMOD                                          Emex Mode
# 43             XOFF                                             Offset
# 39             XVOL                                       Emex Voltage
# 9              ZRCS               Tool Zero Reference Check at Surface
#
#                                                  Value
# 48   [[0.0, 0.00039999998989515007, -0.000899999984...
# 53                                                 [8]
# 58                                               [179]
# 51                                                 [0]
# 56                                                [86]
# 60                                           [PRESENT]
# 72                                           [HAMMING]
# 0                                [SPEEDCORRECTEDDEPTH]
# 317                                                 []
# 369                                             [39.5]
# 436  [                                             ...
# 62                                              [25.0]
# 55                                        [1013894691]
# 466                               [2.7432000637054443]
# 325                                                 []
# 81                                              [OPEN]
# 85                                             [160.0]
# 278                                [0.800000011920929]
# 365                                           [4815.0]
# 327                                                 []
# 323                                                 []
# 322                                                 []
# 355                                             [5.75]
# 336                                          [51000.0]
# 364                                                 []
# 363                                                 []
# 326                                                 []
# 385  [                                             ...
# 361                                                 []
# 96                                              [50.0]
# 421  [                                             ...
# 388  [                                             ...
# 360                                           [4599.0]
# 359                                           [4609.0]
# 315                                           [4599.0]
# 334                                                 []
# 362                                                 []
# 287                                            [100.0]
# 387                                          [Primary]
# 452  [Rig:                                         ...
# 448  [Wintershall Noordzee B.V.                    ...
# 447  [                                             ...
# 275                                             [40.0]
# 429  [                                             ...
# 6                                           [WIRELINE]
# 274                                            [180.0]
# 444  [Glomar Adriatic XI                           ...
# 297                                               [2L]
# 354                                              [7.0]
# 280                                              [0.0]
# 357                                                 []
# 353                                              [0.0]
# 333                                                 []
# 428  [17-Feb-2002                                  ...
# 139                                              [0.0]
# 138                                              [0.0]
# 137                                              [0.0]
# 136                                              [0.0]
# 123                                             [75.0]
# 122                                             [75.0]
# 121                                            [180.0]
# 120                                             [40.0]
# 419  [15-Feb-2002                                  ...
# 135                                            [825.0]
# 134                                            [825.0]
# 133                                           [1620.0]
# 132                                            [360.0]
# 244                                                [0]
# 236                                                [0]
# 228                                                [0]
# 220                                                [0]
# 212                                                [0]
# 254                                                [0]
# 289                                       [AUTOMATIC_]
# 288                                       [AUTOMATIC_]
# 28                                                  []
# 27                                                  []
# 26                                                  []
# 25                                                  []
# 24                                                  []
# 23                                                  []
# 352                               [13.100000381469727]
# 350                                                 []
# 349                                              [9.5]
# 420  [Therma-Drill WBM                             ...
# 351                                             [65.0]
# 36                               [0.30480000376701355]
# 426  [17-Feb-2002                                  ...
# 114                                              [USE]
# 115                                               [C1]
# 437  [RT                                           ...
# 457                                              [0.0]
# 300                                             [NONE]
# 76                                              [STAN]
# 271                                             [75.0]
# 270                                            [775.0]
# 245                                               [40]
# 237                                               [40]
# 229                                               [40]
# 221                                               [10]
# 213                                               [10]
# 255                                               [40]
# 113                                          [PS_COMP]
# 286                                            [189.0]
# 285                                             [56.0]
# 112                                     [UPPER_DIPOLE]
# 290                                       [AUTOMATIC_]
# 292                                             [T5T7]
# 291                                           [350KBS]
# 243                                              [512]
# 235                                              [512]
# 227                                              [512]
# 219                                              [512]
# 211                                              [512]
# 253                                              [512]
# 372                                             [39.5]
# 373                                            [-37.0]
# 374                                             [39.5]
# 296                                              [0.5]
# 371                                             [39.5]
# 463                                    [FTB_TELEMETRY]
# 370                                              [0.0]
# 41                                           [ALL_DIP]
# 314                                              [4.5]
# 284                                              [1.0]
# 205                                               [40]
# 98                                        [COMP_SHEAR]
# 442  [North Sea                                    ...
# 441  [Dutch Sector                                 ...
# 440  [                                             ...
# 358                                                 []
# 455                                               [NO]
# 206                                              [500]
# 91                                              [40.0]
# 89                                          [CONTINUE]
# 207                                               [UP]
# 90                                             [180.0]
# 445  [L5                                           ...
# 259                                             [NONE]
# 465                                              [400]
# 84                                                [C1]
# 78                                               [0.0]
# 240                                              [800]
# 232                                              [800]
# 224                                              [800]
# 216                                              [160]
# 208                                              [160]
# 250                                              [800]
# 328                                                 []
# 77                              [0.018226999789476395]
# 241                                            [15360]
# 233                                            [15360]
# 225                                            [15360]
# 217                                             [2560]
# 209                                             [1600]
# 251                                            [15360]
# 64                                              [DIPM]
# 279                                              [2.0]
# 82                                              [GEN9]
# 63                                              [DIPM]
# 79                                              [TEMP]
# 390  [16-Feb-2002                                  ...
# 391  [Run B2                                       ...
# 389  [FMS-DSI-GR-ACTS                              ...
# 392                                          [INCLUDE]
# 312                                            [C1/C2]
# 324                                                 []
# 71                               [AUTOMATIC_SELECTION]
# 33                                       [dd-MMM-yyyy]
# 19                                                  []
# 8                                              [7-46P]
# 22                                                  []
# 34                                             [IDW-B]
# 21                                                  []
# 20                                                  []
# 313                                             [SNAP]
# 379  [                                             ...
# 378  [                                             ...
# 302                               [2.4384000301361084]
# 75                                            [BARITE]
# 283                                             [DTCO]
# 37                                             [ALLOW]
# 258                                           [959250]
# 70                                 [53.75031280517578]
# 435  [53 42' 18.113"                               ...
# 376                                              [440]
# 460                                             [6500]
# 386  [                                             ...
# 461                                                [ ]
# 16                                                  []
# 335                                                 []
# 97                                        [COMP_FIRST]
# 451  [SECTION                                      ...
# 438  [RT                                           ...
# 454                                   [MEASURED_DEPTH]
# 5                                  [FIRST_LOG_IN_WELL]
# 69                                 [4.634794235229492]
# 434  [04 36' 12.526"                               ...
# 263                                             [NONE]
# 262                                         [RECEIVER]
# 261                                             [NONE]
# 260                                            [DDBHC]
# 477                                              [156]
# 424  [HWL                                          ...
# 377                                              [501]
# 52                                                 [4]
# 57                                               [175]
# 50                                                 [3]
# 54                                                [93]
# 92                                                [42]
# 59                                           [PRESENT]
# 83                                              [LIME]
# 276                               [3.0480000972747803]
# 111                                             [57.0]
# 415  [                                             ...
# 343                                             [14.0]
# 68                               [-1.3856151103973389]
# 88                                              [20.0]
# 67                                 [39.02876281738281]
# 416  [                                             ...
# 345                               [15.499999046325684]
# 47   [[-0.003399999812245369, 0.012799999676644802,...
# 356                                [8.350000381469727]
# 66                                 [68.35118103027344]
# 46                                              [FSCA]
# 2                                               [FEET]
# 337                                            [160.0]
# 340                                            [159.0]
# 339                                            [159.0]
# 338                                            [160.0]
# 61                                              [13.0]
# 277                                [3.554243803024292]
# 417  [Flowline                                     ...
# 347                                             [17.0]
# 49                                        [1013894693]
# 475                                              [186]
# 430  [Netherlands                                  ...
# 316                                                 []
# 242                                                [1]
# 234                                                [1]
# 226                                                [1]
# 218                                                [1]
# 210                                                [1]
# 252                                                [1]
# 329                                                 []
# 375                                                 []
# 414  [MSFL-ARI-IPLT-ACTS                           ...
# 413  [CIS-Seismic                                  ...
# 412  [MDT-GR-ACTS                                  ...
# 411  [                                             ...
# 410  [                                             ...
# 65                                               [0.5]
# 456                                               [NO]
# 439  [MSL                                          ...
# 458                                        [RECOMPUTE]
# 38                                                [HR]
# 380  [9C2-303                                      ...
# 409  [Log Correlated to DLT-GR-SLS-MSFL-CAL-AMS 21-...
# 400  [Borehole rugosity having slight affect on the...
# 399  [TD not Tagged due to Sticky hole conditions, ...
# 398  [                                             ...
# 397  [                                             ...
# 396  [                                             ...
# 395  [                                             ...
# 394  [                                             ...
# 393  [                                             ...
# 408  [GR was logged up to 4495 m to give an overlap...
# 407  [Tool String configured as per tool sketch wit...
# 406  [                                             ...
# 405  [                                             ...
# 404  [                                             ...
# 403  [                                             ...
# 401  [                                             ...
# 431  [                                             ...
# 257                                              [R15]
# 42                                              [AUTO]
# 4                                                  [ ]
# 449  [RANGE                                        ...
# 31                                       [dd-MMM-yyyy]
# 30                                                  []
# 29                                                  []
# 342                             [0.039910536259412766]
# 344                               [0.5199999809265137]
# 341                             [0.025503424927592278]
# 346                                            [0.125]
# 348                              [0.18799999356269836]
# 95                                 [1.399999976158142]
# 94                                 [2.119999885559082]
# 10                                               [0.0]
# 11                                               [0.0]
# 427  [B2                                           ...
# 320                                              [1.0]
# 474                                              [294]
# 473                                              [300]
# 472                                              [306]
# 471                                              [312]
# 470                                              [318]
# 469                                              [324]
# 468                                              [330]
# 467                                              [336]
# 246                                              [OFF]
# 238                                              [ODD]
# 230                                              [OFF]
# 222                                             [EVEN]
# 214                                              [OFF]
# 256                                              [OFF]
# 303                                             [70.0]
# 171                                              [255]
# 170                                              [255]
# 169                                              [255]
# 168                                              [255]
# 93                                               [255]
# 180                                           [3000.0]
# 179                                           [3000.0]
# 178                                           [3000.0]
# 177                                            [500.0]
# 172                                               [ON]
# 298                                              [MSD]
# 184                                           [8000.0]
# 183                                           [8000.0]
# 182                                           [8000.0]
# 181                                           [2000.0]
# 1                                               [GPIT]
# 13                                                  []
# 295                               [0.8999999761581421]
# 433  [                                             ...
# 200                                       [SELECTABLE]
# 199                                       [SELECTABLE]
# 198                                       [SELECTABLE]
# 197                                       [SELECTABLE]
# 176                                            [B1-3K]
# 175                                            [B1-3K]
# 174                                         [B.5-1.5K]
# 173                                           [B3-20K]
# 131                                            [825.0]
# 130                                            [825.0]
# 129                                           [1620.0]
# 128                                            [360.0]
# 119                                             [75.0]
# 118                                             [75.0]
# 117                                            [180.0]
# 116                                             [40.0]
# 321                                                 []
# 127                                          [13525.0]
# 126                                          [15525.0]
# 125                                          [12020.0]
# 124                                           [3660.0]
# 273                                             [75.0]
# 80                                              [20.0]
# 272                                            [180.0]
# 462                                              [0.0]
# 453  [Country:                                     ...
# 192                                             [75.0]
# 191                                             [75.0]
# 190                                            [180.0]
# 189                                             [40.0]
# 45                                              [-1.0]
# 73                                               [0.5]
# 381  [                                             ...
# 299                                              [1/4]
# 309                                              [0.0]
# 459                                             [1800]
# 282                                              [R-H]
# 267                                             [NONE]
# 266                                         [RECEIVER]
# 265                                             [NONE]
# 264                                            [DDBHC]
# 310                                              [0.0]
# 281                                             [DTCO]
# 308                                              [0.0]
# 147                                              [4.0]
# 146                                              [4.0]
# 145                                              [4.0]
# 144                                              [2.0]
# 203                                          [WF_SAM1]
# 202                                          [WF_SAM2]
# 201                                          [WF_SAM4]
# 443  [Netherlands                                  ...
# 293                                              [0.0]
# 294                                              [0.0]
# 12                                                  []
# 318                                                 []
# 301                               [1.2192000150680542]
# 269                                            [180.0]
# 268                                            [780.0]
# 188                                            [775.0]
# 187                                            [775.0]
# 186                                            [780.0]
# 185                                            [240.0]
# 143                                             [40.0]
# 142                                             [40.0]
# 141                                             [40.0]
# 140                                             [10.0]
# 311                                              [0.0]
# 196                                                [0]
# 195                                                [0]
# 194                                                [0]
# 193                                              [300]
# 383  [                                             ...
# 331                                                 []
# 418  [5:30                                         ...
# 384  [                                             ...
# 332                                                 []
# 330                                                 []
# 3                                             [4825.0]
# 368                                           [4825.0]
# 367                                           [4828.0]
# 100                                             [15.0]
# 99                                              [15.0]
# 306                                              [0.0]
# 304                                              [0.0]
# 307                                              [0.0]
# 305                                              [0.0]
# 425  [2:36                                         ...
# 366                                           [4609.0]
# 167                                            [600.0]
# 166                                            [600.0]
# 165                                            [600.0]
# 164                                            [150.0]
# 450  [TOWNSHIP                                     ...
# 86                                                [60]
# 32                                       [dd-MMM-yyyy]
# 18                                                  []
# 15                                               [1.0]
# 14                                               [0.0]
# 17                                                  []
# 7                                           [CMTD-B/A]
# 432  [                                             ...
# 74                                        [ECCENTERED]
# 35                                            [1000.0]
# 87                                                [10]
# 155                                            [200.0]
# 154                                            [200.0]
# 153                                            [200.0]
# 152                                             [50.0]
# 163                                          [13525.0]
# 162                                          [15525.0]
# 161                                          [12000.0]
# 160                                           [3660.0]
# 151                                           [2000.0]
# 150                                           [2000.0]
# 149                                           [2000.0]
# 148                                           [1000.0]
# 159                                           [1600.0]
# 158                                           [1600.0]
# 157                                           [2400.0]
# 156                                            [500.0]
# 249                                                [5]
# 319                                            [100.0]
# 248                                                [0]
# 464                                      [TRADITIONAL]
# 476                                              [162]
# 382  [                                             ...
# 479                                              [0.0]
# 478                                              [0.0]
# 102                                              [0.0]
# 101                                              [0.0]
# 110                                             [15.0]
# 109                                              [5.0]
# 104                                              [3.0]
# 103                                              [3.0]
# 239                                               [W1]
# 231                                               [W1]
# 223                                               [W1]
# 215                                               [W1]
# 204                                               [W1]
# 247                                               [W1]
# 446  [L5-9                                         ...
# 108                                             [15.0]
# 107                                             [15.0]
# 106                                              [3.0]
# 105                                              [3.0]
# 44                                                 [3]
# 40                                            [MANUAL]
# 43                                                 [0]
# 39                                                 [0]
# 9                                                   []

# %% [markdown]
# ### Channels
#
# The channels within a frame are the individual curves or arrays. To view a quick summary of these, we can pass in a number of attributes to the `summary_dataframe()` method.

# %%
channels = summary_dataframe(f.channels, name='Name', long_name='Long Name', dimension='Dimension', units='Units', frame='Frame')
channels
# Out:
#                              Name  \
# 303                           ABS
# 302                          AFCD
# 12                           ANOR
# 455                       ANOR_SL
# 301                          AREA
# 427                            AX
# 464                         AX_SL
# 428                            AY
# 465                         AY_SL
# 429                            AZ
# 440                         AZS1G
# 441                         AZS2G
# 439                         AZSNG
# 98                           AZTB
# 101                          AZWD
# 466                         AZ_SL
# 336                          BA11
# 337                          BA12
# 325                          BA13
# 338                          BA14
# 339                          BA15
# 340                          BA16
# 320                          BA17
# 341                          BA18
# 342                          BA21
# 329                          BA22
# 330                          BA23
# 331                          BA24
# 333                          BA25
# 334                          BA26
# 335                          BA27
# 319                          BA28
# 363                          BB11
# 364                          BB12
# 326                          BB13
# 365                          BB14
# 366                          BB15
# 367                          BB16
# 321                          BB17
# 368                          BB18
# 369                          BB21
# 356                          BB22
# 357                          BB23
# 358                          BB24
# 360                          BB25
# 361                          BB26
# 362                          BB27
# 324                          BB28
# 343                          BC11
# 344                          BC12
# 322                          BC13
# 345                          BC14
# 346                          BC15
# 347                          BC16
# 327                          BC17
# 348                          BC18
# 349                          BC21
# 350                          BC22
# 351                          BC23
# 352                          BC24
# 353                          BC25
# 354                          BC26
# 355                          BC27
# 332                          BC28
# 370                          BD11
# 371                          BD12
# 323                          BD13
# 372                          BD14
# 373                          BD15
# 374                          BD16
# 328                          BD17
# 375                          BD18
# 376                          BD21
# 377                          BD22
# 378                          BD23
# 379                          BD24
# 380                          BD25
# 381                          BD26
# 382                          BD27
# 359                          BD28
# 24                           BHPR
# 23                           BHRM
# 71                             BI
# 72                           BILI
# 2                              BS
# 421                            C1
# 105                          C1R1
# 138                          C1R3
# 116                          C1T1
# 128                          C1T2
# 149                          C1T3
# 422                            C2
# 109                          C2R1
# 142                          C2R3
# 120                          C2T1
# 132                          C2T2
# 153                          C2T3
# 69                           CBLF
# 285                           CDF
# 173                          CER1
# 199                          CER3
# 181                          CET1
# 191                          CET2
# 207                          CET3
# 170                          CHR1
# 186                          CHR2
# 196                          CHR3
# 229                          CHR5
# 213                          CHRP
# 215                          CHRS
# 178                          CHT1
# 188                          CHT2
# 204                          CHT3
# 231                          CHT5
# 217                          CHTP
# 219                          CHTS
# 295                          CLOS
# 3                              CS
# 4                            CVEL
# 296                          CWEL
# 384                           DB1
# 417                           DB1
# 416                          DB1A
# 389                          DB1A
# 415                           DB2
# 385                           DB2
# 414                          DB2A
# 390                          DB2A
# 391                           DB3
# 412                           DB3
# 411                          DB3A
# 386                          DB3A
# 392                           DB4
# 410                           DB4
# 409                          DB4A
# 387                          DB4A
# 304                          DCAL
# 61                      DCD_CALI1
# 62                      DCD_CALI2
# 60                         DCD_PA
# 63                  DCD_PA_100_BI
# 64                   DCD_PA_80_BI
# 65                        DCD_PIS
# 66                   DCD_STANDOFF
# 93                           DCI1
# 94                           DCI2
# 95                           DCI3
# 96                           DCI4
# 97                           DCI5
# 92                           DCIX
# 294                           DDA
# 293                          DDIP
# 8                            DEVI
# 284                            DF
# 290                          DPAZ
# 289                          DPTR
# 479                      DSST_FRR
# 480                     DSST_FRRB
# 482                     DSST_PGTC
# 483                     DSST_PNTC
# 481                     DSST_PWTC
# 220                           DT1
# 176                          DT1R
# 184                          DT1T
# 221                           DT2
# 187                          DT2R
# 194                          DT2T
# 202                          DT3R
# 210                          DT3T
# 223                          DT4P
# 224                          DT4S
# 225                           DT5
# 230                          DT5R
# 232                          DT5T
# 166                          DTCO
# 212                          DTRP
# 214                          DTRS
# 167                          DTSM
# 222                          DTST
# 216                          DTTP
# 218                          DTTS
# 99                           DVTB
# 102                          DVWD
# 108                          E1R1
# 141                          E1R3
# 119                          E1T1
# 131                          E1T2
# 152                          E1T3
# 111                          E2R1
# 144                          E2R3
# 122                          E2T1
# 134                          E2T2
# 155                          E2T3
# 21                           ECGR
# 297                            ED
# 175                          EER1
# 201                          EER3
# 183                          EET1
# 193                          EET2
# 209                          EET3
# 311                          EHGR
# 423                            EI
# 171                          ENR1
# 197                          ENR3
# 179                          ENT1
# 189                          ENT2
# 205                          ENT3
# 6                            ETIM
# 318                            EV
# 435                          FCAX
# 436                          FCAY
# 437                          FCAZ
# 305                           FCD
# 14                           FINC
# 457                       FINC_SL
# 13                           FNOR
# 456                       FNOR_SL
# 226                          FSK5
# 238                          FTC5
# 438                          FTIM
# 237                          FTT5
# 430                            FX
# 467                         FX_SL
# 431                            FY
# 468                         FY_SL
# 432                            FZ
# 469                         FZ_SL
# 472                       GADZ_SL
# 19                            GAT
# 475                        GAT_SL
# 22                            GHD
# 20                            GMT
# 476                        GMT_SL
# 474                        GNV_SL
# 70                           GOBO
# 473                        GPV_SL
# 446                            GR
# 25                           GTEM
# 15                           HAZI
# 458                       HAZI_SL
# 306                          HDAR
# 450                           HGR
# 308                           ICV
# 314                          IDWD
# 307                           IHV
# 67                            ITT
# 174                          LFR1
# 200                          LFR3
# 182                          LFT1
# 192                          LFT2
# 208                          LFT3
# 7                            MARK
# 264                        MAXSP1
# 269                        MAXSP2
# 274                        MAXSP3
# 279                        MAXSP4
# 259                        MAXSPX
# 233                           MD5
# 234                          MDR5
# 236                          MDT5
# 235                          MNU5
# 10                           MSW1
# 11                           MSW2
# 298                            ND
# 104                          NPR1
# 137                          NPR3
# 115                          NPT1
# 127                          NPT2
# 148                          NPT3
# 16                           P1AZ
# 9                       P1AZ_MEST
# 459                       P1AZ_SL
# 53                           PFC5
# 32                           PFCX
# 54                           PFD5
# 33                           PFDX
# 55                           PFN5
# 34                           PFNX
# 51                           PFT5
# 30                           PFTX
# 52                           PFV5
# 31                           PFVX
# 168                            PR
# 57                           PTC5
# 36                           PTCX
# 58                           PTD5
# 37                           PTDX
# 59                           PTN5
# 38                           PTNX
# 228                          PTT5
# 56                           PTX5
# 35                           PTXX
# 40                           PWD1
# 43                           PWD2
# 46                           PWD3
# 49                           PWD4
# 28                           PWDX
# 39                           PWF1
# 112                        PWF1FL
# 245                      PWF1LLSP
# 243                        PWF1SP
# 244                      PWF1SPDB
# 246                      PWF1ULSP
# 42                           PWF2
# 125                        PWF2FL
# 249                      PWF2LLSP
# 247                        PWF2SP
# 248                      PWF2SPDB
# 250                      PWF2ULSP
# 45                           PWF3
# 145                        PWF3FL
# 253                      PWF3LLSP
# 251                        PWF3SP
# 252                      PWF3SPDB
# 254                      PWF3ULSP
# 48                           PWF4
# 158                        PWF4FL
# 257                      PWF4LLSP
# 255                        PWF4SP
# 256                      PWF4SPDB
# 258                      PWF4ULSP
# 27                           PWFX
# 241                      PWFXLLSP
# 239                        PWFXSP
# 240                      PWFXSPDB
# 242                      PWFXULSP
# 41                           PWN1
# 44                           PWN2
# 47                           PWN3
# 50                           PWN4
# 29                           PWNX
# 291                          QUAF
# 17                             RB
# 100                          RBTB
# 103                          RBWD
# 460                         RB_SL
# 444                           RGR
# 449                          RHGR
# 106                          S1R1
# 139                          S1R3
# 117                          S1T1
# 129                          S1T2
# 150                          S1T3
# 161                          SAS1
# 162                          SAS2
# 163                          SAS3
# 164                          SAS4
# 418                           SB1
# 383                           SB1
# 388                           SB2
# 413                           SB2
# 315                           SCD
# 18                           SDEV
# 461                       SDEV_SL
# 227                          SLK5
# 114                          SNR1
# 147                          SNR3
# 124                          SNT1
# 136                          SNT2
# 157                          SNT3
# 165                          SOBS
# 286                          SPCF
# 68                           SPHI
# 113                          SPR1
# 126                          SPR2
# 146                          SPR3
# 159                          SPR4
# 123                          SPT1
# 135                          SPT2
# 156                          SPT3
# 160                          SPT4
# 75                           SSVE
# 445                          STSG
# 74                           SVEL
# 107                          T1R1
# 140                          T1R3
# 118                          T1T1
# 130                          T1T2
# 151                          T1T3
# 110                          T2R1
# 143                          T2R3
# 121                          T2T1
# 133                          T2T2
# 154                          T2T3
# 478                          TDEP
# 471                          TDEP
# 463                          TDEP
# 454                          TDEP
# 419                          TDEP
# 447                          TDEP
# 442                          TDEP
# 433                          TDEP
# 425                          TDEP
# 451                          TDEP
# 316                          TDEP
# 0                            TDEP
# 309                          TDEP
# 312                          TDEP
# 26                           TEMP
# 5                            TENS
# 172                          TER1
# 198                          TER3
# 180                          TET1
# 190                          TET2
# 206                          TET3
# 443                          TIME
# 420                          TIME
# 313                          TIME
# 477                          TIME
# 310                          TIME
# 317                          TIME
# 470                          TIME
# 434                          TIME
# 1                            TIME
# 462                          TIME
# 453                          TIME
# 452                          TIME
# 426                          TIME
# 448                          TIME
# 177                          TTR1
# 203                          TTR3
# 185                          TTT1
# 195                          TTT2
# 211                          TTT3
# 299                          TVDE
# 288                  U-DIP_CENTER
# 287                 U-DIP_COSLOPE
# 292                   U-DIP_SLOPE
# 424                        U-MBAV
# 401                    U-MEST_RB1
# 402                    U-MEST_RB2
# 403                    U-MEST_RB3
# 404                    U-MEST_RB4
# 405                    U-MEST_RB5
# 406                    U-MEST_RB6
# 407                    U-MEST_RB7
# 408                    U-MEST_RB8
# 393    U-MEST_RESISTIVITY_PADA_DS
# 397   U-MEST_RESISTIVITY_PADA_EQU
# 394    U-MEST_RESISTIVITY_PADB_DS
# 398   U-MEST_RESISTIVITY_PADB_EQU
# 395    U-MEST_RESISTIVITY_PADC_DS
# 399   U-MEST_RESISTIVITY_PADC_EQU
# 396    U-MEST_RESISTIVITY_PADD_DS
# 400   U-MEST_RESISTIVITY_PADD_EQU
# 73   U-SONIC_BI_PIPS_DATA_CHANNEL
# 169                          VPVS
# 300                          VSEC
# 81                           WCI1
# 84                           WCI2
# 87                           WCI3
# 90                           WCI4
# 91                           WCI5
# 78                           WCIX
# 79                            WF1
# 267                       WF1LLSP
# 265                         WF1SP
# 266                       WF1SPDB
# 268                       WF1ULSP
# 82                            WF2
# 272                       WF2LLSP
# 270                         WF2SP
# 271                       WF2SPDB
# 273                       WF2ULSP
# 85                            WF3
# 277                       WF3LLSP
# 275                         WF3SP
# 276                       WF3SPDB
# 278                       WF3ULSP
# 88                            WF4
# 282                       WF4LLSP
# 280                         WF4SP
# 281                       WF4SPDB
# 283                       WF4ULSP
# 80                           WFG1
# 83                           WFG2
# 86                           WFG3
# 89                           WFG4
# 77                           WFGX
# 76                            WFX
# 262                       WFXLLSP
# 260                         WFXSP
# 261                       WFXSPDB
# 263                       WFXULSP
#
#                                              Long Name    Dimension  \
# 303                                        Area of Bit          [1]
# 302                              Area of Future Casing          [1]
# 12                          Acceleration Computed Norm          [1]
# 455                         Acceleration Computed Norm          [1]
# 301                                   Area of Borehole          [1]
# 427                                     X Acceleration          [1]
# 464                                     X Acceleration          [1]
# 428                                     Y Acceleration          [1]
# 465                                     Y Acceleration          [1]
# 429                                     Z Acceleration          [1]
# 440                           GPIT Symply-Summed Gamma          [1]
# 441                           GPIT Doubly-Summed Gamma          [1]
# 439                   GPIT Number  Acc. Samples(FLOAT)          [1]
# 98                         Azimuth at DSST Tool Bottom          [1]
# 101                          Azimuth at Waveform Depth          [1]
# 466                                     Z Acceleration          [1]
# 336                         CALIBRATED DATA BUTTON A11          [1]
# 337                         CALIBRATED DATA BUTTON A12          [1]
# 325                         CALIBRATED DATA BUTTON A13          [1]
# 338                         CALIBRATED DATA BUTTON A14          [1]
# 339                         CALIBRATED DATA BUTTON A15          [1]
# 340                         CALIBRATED DATA BUTTON A16          [1]
# 320                         CALIBRATED DATA BUTTON A17          [1]
# 341                         CALIBRATED DATA BUTTON A18          [1]
# 342                         CALIBRATED DATA BUTTON A21          [1]
# 329                         CALIBRATED DATA BUTTON A22          [1]
# 330                         CALIBRATED DATA BUTTON A23          [1]
# 331                         CALIBRATED DATA BUTTON A24          [1]
# 333                         CALIBRATED DATA BUTTON A25          [1]
# 334                         CALIBRATED DATA BUTTON A26          [1]
# 335                         CALIBRATED DATA BUTTON A27          [1]
# 319                         CALIBRATED DATA BUTTON A28          [1]
# 363                         CALIBRATED DATA BUTTON B11          [1]
# 364                         CALIBRATED DATA BUTTON B12          [1]
# 326                         CALIBRATED DATA BUTTON B13          [1]
# 365                         CALIBRATED DATA BUTTON B14          [1]
# 366                         CALIBRATED DATA BUTTON B15          [1]
# 367                         CALIBRATED DATA BUTTON B16          [1]
# 321                         CALIBRATED DATA BUTTON B17          [1]
# 368                         CALIBRATED DATA BUTTON B18          [1]
# 369                         CALIBRATED DATA BUTTON B21          [1]
# 356                         CALIBRATED DATA BUTTON B22          [1]
# 357                         CALIBRATED DATA BUTTON B23          [1]
# 358                         CALIBRATED DATA BUTTON B24          [1]
# 360                         CALIBRATED DATA BUTTON B25          [1]
# 361                         CALIBRATED DATA BUTTON B26          [1]
# 362                         CALIBRATED DATA BUTTON B27          [1]
# 324                         CALIBRATED DATA BUTTON B28          [1]
# 343                         CALIBRATED DATA BUTTON C11          [1]
# 344                         CALIBRATED DATA BUTTON C12          [1]
# 322                         CALIBRATED DATA BUTTON C13          [1]
# 345                         CALIBRATED DATA BUTTON C14          [1]
# 346                         CALIBRATED DATA BUTTON C15          [1]
# 347                         CALIBRATED DATA BUTTON C16          [1]
# 327                         CALIBRATED DATA BUTTON C17          [1]
# 348                         CALIBRATED DATA BUTTON C18          [1]
# 349                         CALIBRATED DATA BUTTON C21          [1]
# 350                         CALIBRATED DATA BUTTON C22          [1]
# 351                         CALIBRATED DATA BUTTON C23          [1]
# 352                         CALIBRATED DATA BUTTON C24          [1]
# 353                         CALIBRATED DATA BUTTON C25          [1]
# 354                         CALIBRATED DATA BUTTON C26          [1]
# 355                         CALIBRATED DATA BUTTON C27          [1]
# 332                         CALIBRATED DATA BUTTON C28          [1]
# 370                         CALIBRATED DATA BUTTON D11          [1]
# 371                         CALIBRATED DATA BUTTON D12          [1]
# 323                         CALIBRATED DATA BUTTON D13          [1]
# 372                         CALIBRATED DATA BUTTON D14          [1]
# 373                         CALIBRATED DATA BUTTON D15          [1]
# 374                         CALIBRATED DATA BUTTON D16          [1]
# 328                         CALIBRATED DATA BUTTON D17          [1]
# 375                         CALIBRATED DATA BUTTON D18          [1]
# 376                         CALIBRATED DATA BUTTON D21          [1]
# 377                         CALIBRATED DATA BUTTON D22          [1]
# 378                         CALIBRATED DATA BUTTON D23          [1]
# 379                         CALIBRATED DATA BUTTON D24          [1]
# 380                         CALIBRATED DATA BUTTON D25          [1]
# 381                         CALIBRATED DATA BUTTON D26          [1]
# 382                         CALIBRATED DATA BUTTON D27          [1]
# 359                         CALIBRATED DATA BUTTON D28          [1]
# 24                                   Borehole Pressure          [1]
# 23                            Borehole Mud Resistivity          [1]
# 71                                          Bond Index          [1]
# 72                 Bond Index Level for Zone Isolation          [1]
# 2                                             Bit Size          [1]
# 421                                          Caliper 1          [1]
# 105  STC Peak Coherence, Receiver Array - Lower Dipole         [16]
# 138  STC Peak Coherence, Receiver Array - Monopole ...         [16]
# 116  STC Peak Coherence, Transmitter Array - Lower ...         [16]
# 128  STC Peak Coherence, Transmitter Array - Upper ...         [16]
# 149  STC Peak Coherence, Transmitter Array - Monopo...         [16]
# 422                                          Caliper 2          [1]
# 109  STC Energy Peak Coherence, Receiver Array - Lo...         [16]
# 142  STC Energy Peak Coherence, Receiver Array - Mo...         [16]
# 120  STC Energy Peak Coherence, Transmitter Array -...         [16]
# 132  STC Energy Peak Coherence, Transmitter Array -...         [16]
# 153  STC Energy Peak Coherence, Transmitter Array -...         [16]
# 69                   CBL Amplitude (Fluid Compensated)          [1]
# 285                          Calibrated Downhole Force          [1]
# 173  Label Energy Peak Coherence, Receiver Array - ...          [1]
# 199  Label Energy Peak Coherence, Receiver Array - ...          [1]
# 181  Label Energy Peak Coherence, Transmitter Array...          [1]
# 191  Label Energy Peak Coherence, Transmitter Array...          [1]
# 207  Label Energy Peak Coherence, Transmitter Array...          [1]
# 170  Label Peak Coherence, Receiver Array - Lower D...          [1]
# 186  Label Peak Coherence, Receiver Array - Upper D...          [1]
# 196  Label Peak Coherence, Receiver Array - Monopol...          [1]
# 229               Peak Coherence, Receiver Array - FMD          [1]
# 213  Label Peak Coherence, Receiver Array, Compress...          [1]
# 215  Label Peak Coherence, Receiver Array, Shear - ...          [1]
# 178  Label Peak Coherence, Transmitter Array - Lowe...          [1]
# 188  Label Peak Coherence, Transmitter Array - Uppe...          [1]
# 204  Label Peak Coherence, Transmitter Array - Mono...          [1]
# 231            Peak Coherence, Transmitter Array - FMD          [1]
# 217  Label Peak Coherence, Transmitter Array, Compr...          [1]
# 219  Label Peak Coherence, Transmitter Array, Shear...          [1]
# 295                                            Closure          [1]
# 3                                          Cable Speed          [1]
# 4                                       Cable Velocity          [1]
# 296                              Curvature of the Well          [1]
# 384                           CALIBRATED DATA BUTTON 1          [1]
# 417                           CALIBRATED DATA BUTTON 1          [1]
# 416                          CALIBRATED DATA BUTTON 1A          [1]
# 389                          CALIBRATED DATA BUTTON 1A          [1]
# 415                           CALIBRATED DATA BUTTON 2          [1]
# 385                           CALIBRATED DATA BUTTON 2          [1]
# 414                          CALIBRATED DATA BUTTON 2A          [1]
# 390                          CALIBRATED DATA BUTTON 2A          [1]
# 391                           CALIBRATED DATA BUTTON 3          [1]
# 412                           CALIBRATED DATA BUTTON 3          [1]
# 411                          CALIBRATED DATA BUTTON 3A          [1]
# 386                          CALIBRATED DATA BUTTON 3A          [1]
# 392                           CALIBRATED DATA BUTTON 4          [1]
# 410                           CALIBRATED DATA BUTTON 4          [1]
# 409                          CALIBRATED DATA BUTTON 4A          [1]
# 387                          CALIBRATED DATA BUTTON 4A          [1]
# 304                               Differential Caliper          [1]
# 61               First Caliper From Dowell Cement Data          [1]
# 62              Second Caliper From Dowell Cement Data          [1]
# 60       Predicted Attenuation From Dowell Cement Data          [1]
# 63   Predicted Amplitude for 100 % BI From Dowell C...          [1]
# 64   Predicted Amplitude for 80 % BI From Dowell Ce...          [1]
# 65   Predicted Impedance Of Slurry From Dowell Ceme...          [1]
# 66                    Standoff From Dowell Cement Data          [1]
# 93                  Data Copy Indicator - Lower Dipole          [1]
# 94                  Data Copy Indicator - Upper Dipole          [1]
# 95             Data Copy Indicator - Monopole Stoneley          [1]
# 96                  Data Copy Indicator - Monopole P&S          [1]
# 97                           Data Copy Indicator - FMD          [1]
# 92                        Data Copy Indicator - Expert          [1]
# 294                           DIFFERENTIAL DIP AZIMUTH          [1]
# 293                             DIFFERENTIAL DIP ANGLE          [1]
# 8                                            Deviation          [1]
# 284                        Uncalibrated Downhole Force          [1]
# 290                                        DIP AZIMUTH          [1]
# 289                                          DIP TREND          [1]
# 479                DSST Frequency Range for Tool Check  [4, 8, 256]
# 480        DSST Frequency Range Decibel for Tool Check  [4, 8, 256]
# 482  DSST Packed Waveform Gain Code - Expert for To...       [4, 8]
# 483  DSST Packed Waveform Normalization Factors - E...       [4, 8]
# 481  DSST Packed Waveform Data - Expert for Tool Check  [4, 8, 480]
# 220                       Delta-T Shear - Lower Dipole          [1]
# 176       Delta-T Shear, Receiver Array - Lower Dipole          [1]
# 184    Delta-T Shear, Transmitter Array - Lower Dipole          [1]
# 221                       Delta-T Shear - Upper Dipole          [1]
# 187       Delta-T Shear, Receiver Array - Upper Dipole          [1]
# 194    Delta-T Shear, Transmitter Array - Upper Dipole          [1]
# 202  Delta-T Stoneley, Receiver Array - Monopole St...          [1]
# 210  Delta-T Stoneley, Transmitter Array - Monopole...          [1]
# 223               Delta-T Compressional - Monopole P&S          [1]
# 224                       Delta-T Shear - Monopole P&S          [1]
# 225                 Delta-T Compressional, DDBHC - FMD          [1]
# 230        Delta-T Compressional, Receiver Array - FMD          [1]
# 232     Delta-T Compressional, Transmitter Array - FMD          [1]
# 166                              Delta-T Compressional          [1]
# 212  Delta-T Compressional, Receiver Array - Monopo...          [1]
# 214       Delta-T Shear, Receiver Array - Monopole P&S          [1]
# 167                                      Delta-T Shear          [1]
# 222               Delta-T Stoneley - Monopole Stoneley          [1]
# 216  Delta-T Compressional, Transmitter Array - Mon...          [1]
# 218    Delta-T Shear, Transmitter Array - Monopole P&S          [1]
# 99                       Deviation at DSST Tool Bottom          [1]
# 102                        Deviation at Waveform Depth          [1]
# 108     STC Peak Energy, Receiver Array - Lower Dipole         [16]
# 141  STC Peak Energy, Receiver Array - Monopole Sto...         [16]
# 119  STC Peak Energy, Transmitter Array - Lower Dipole         [16]
# 131  STC Peak Energy, Transmitter Array - Upper Dipole         [16]
# 152  STC Peak Energy, Transmitter Array - Monopole ...         [16]
# 111  STC Energy Peak Energy, Receiver Array - Lower...         [16]
# 144  STC Energy Peak Energy, Receiver Array - Monop...         [16]
# 122  STC Energy Peak Energy, Transmitter Array - Lo...         [16]
# 134  STC Energy Peak Energy, Transmitter Array - Up...         [16]
# 155  STC Energy Peak Energy, Transmitter Array - Mo...         [16]
# 21                                           Gamma-Ray          [1]
# 297                                     East Departure          [1]
# 175  Label Energy Peak Energy, Receiver Array - Low...          [1]
# 201  Label Energy Peak Energy, Receiver Array - Mon...          [1]
# 183  Label Energy Peak Energy, Transmitter Array - ...          [1]
# 193  Label Energy Peak Energy, Transmitter Array - ...          [1]
# 209  Label Energy Peak Energy, Transmitter Array - ...          [1]
# 311                                    HiRes Gamma-Ray          [1]
# 423                                       Emex Current          [1]
# 171   Label Peak Energy, Receiver Array - Lower Dipole          [1]
# 197  Label Peak Energy, Receiver Array - Monopole S...          [1]
# 179  Label Peak Energy, Transmitter Array - Lower D...          [1]
# 189  Label Peak Energy, Transmitter Array - Upper D...          [1]
# 205  Label Peak Energy, Transmitter Array - Monopol...          [1]
# 6                                 Elapsed Logging Time          [1]
# 318                                       Emex Voltage          [1]
# 435                     High Resolution X Acceleration          [1]
# 436                     High Resolution Y Acceleration          [1]
# 437                     High Resolution Z Acceleration          [1]
# 305                             Future Casing Diameter          [1]
# 14                          Magnetic Field Inclination          [1]
# 457                         Magnetic Field Inclination          [1]
# 13                        Magnetic Field Computed Norm          [1]
# 456                       Magnetic Field Computed Norm          [1]
# 226                         Cycle Skip Indicator - FMD          [1]
# 238                       Treshold Crossing Data - FMD         [30]
# 438                     Fast Channels Acquisition Time          [1]
# 237                                 Transit Time - FMD          [1]
# 430                                Magnetometer X-Axis          [1]
# 467                                Magnetometer X-Axis          [1]
# 431                                Magnetometer Y-Axis          [1]
# 468                                Magnetometer Y-Axis          [1]
# 432                                Magnetometer Z-Axis          [1]
# 469                                Magnetometer Z-Axis          [1]
# 472                                      Zero Volt ADC          [1]
# 19                           Accelerometer Temperature          [1]
# 475                          Accelerometer Temperature          [1]
# 22                                   Borehole Diameter          [1]
# 20                            Magnetometer Temperature          [1]
# 476                           Magnetometer Temperature          [1]
# 474                                   Negative Voltage          [1]
# 70                                           Good Bond          [1]
# 473                                   Positive Voltage          [1]
# 446                                          Gamma Ray          [1]
# 25                    Generalized Borehole Temperature          [1]
# 15                                        Hole Azimuth          [1]
# 458                                       Hole Azimuth          [1]
# 306                            Hole Diameter from Area          [1]
# 450                                     HiRes GammaRay          [1]
# 308                           Integrated Cement Volume          [1]
# 314                       Integrated Depth Wheel Depth          [1]
# 307                             Integrated Hole Volume          [1]
# 67                             Integrated Transit Time          [1]
# 174          Label Flag, Receiver Array - Lower Dipole          [1]
# 200     Label Flag, Receiver Array - Monopole Stoneley          [1]
# 182       Label Flag, Transmitter Array - Lower Dipole          [1]
# 192       Label Flag, Transmitter Array - Upper Dipole          [1]
# 208  Label Flag, Transmitter Array - Monopole Stoneley          [1]
# 7                         Magnetic Mark Detector Depth          [1]
# 264                                 Maximum Spectrum 1          [1]
# 269                                 Maximum Spectrum 2          [1]
# 274                                 Maximum Spectrum 3          [1]
# 279                                 Maximum Spectrum 4          [1]
# 259                                 Maximum Spectrum X          [1]
# 233       Multishot Delta-T Compressional, DDBHC - FMD          [1]
# 234  Multishot Delta-T Compressional, Receiver Arra...          [1]
# 236  Multishot Delta-T Compressional, Transmitter A...          [1]
# 235               Multishot Number of Shots Used - FMD          [1]
# 10                                  MEST Status Word 1          [1]
# 11                                  MEST Status Word 2          [1]
# 298                                    North Departure          [1]
# 104  STC Number of Peaks, Receiver Array - Lower Di...          [1]
# 137  STC Number of Peaks, Receiver Array - Monopole...          [1]
# 115  STC Number of Peaks, Transmitter Array - Lower...          [1]
# 127  STC Number of Peaks, Transmitter Array - Upper...          [1]
# 148  STC Number of Peaks, Transmitter Array - Monop...          [1]
# 16                                       Pad 1 Azimuth          [1]
# 9                                       Memorized P1AZ          [1]
# 459                                      Pad 1 Azimuth          [1]
# 53                DSST Packed First Motion Count - FMD          [1]
# 32             DSST Packed First Motion Count - Expert          [1]
# 54                DSST Packed First Motion Depth - FMD          [1]
# 33             DSST Packed First Motion Depth - Expert          [1]
# 55                DSST Packed First Motion Noise - FMD          [1]
# 34             DSST Packed First Motion Noise - Expert          [1]
# 51                 DSST Packed First Motion Time - FMD       [1024]
# 30              DSST Packed First Motion Time - Expert       [1024]
# 52                DSST Packed First Motion Value - FMD       [1024]
# 31             DSST Packed First Motion Value - Expert       [1024]
# 168                                    Poisson's Ratio          [1]
# 57         DSST Packed Threshold Crossing Counts - FMD          [1]
# 36      DSST Packed Threshold Crossing Counts - Expert          [1]
# 58         DSST Packed Threshold Crossing Depths - FMD          [1]
# 37      DSST Packed Threshold Crossing Depths - Expert          [1]
# 59   DSST Packed Threshold Crossing Noise Counts - FMD          [1]
# 38   DSST Packed Threshold Crossing Noise Counts - ...          [1]
# 228                         Packed Transit Times - FMD          [8]
# 56      DSST Packed Threshold Crossing Time Data - FMD      [1, 50]
# 35   DSST Packed Threshold Crossing Time Data - Expert      [1, 50]
# 40           DSST Packed Waveform Depth - Lower Dipole          [1]
# 43           DSST Packed Waveform Depth - Upper Dipole          [8]
# 46      DSST Packed Waveform Depth - Monopole Stoneley          [1]
# 49           DSST Packed Waveform Depth - Monopole P&S          [8]
# 28                 DSST Packed Waveform Depth - Expert       [1, 1]
# 39            DSST Packed Waveform Data - Lower Dipole     [1, 512]
# 112   DSST Packed Waveform STC Filtered - Lower Dipole     [8, 512]
# 245         Packed Waveform Lower Limit for Spectrum 1          [1]
# 243  DSST Packed Waveform Spectrum Linear - Lower D...     [8, 256]
# 244  DSST Packed Waveform Spectrum Decibel - Lower ...     [8, 256]
# 246         Packed Waveform Upper Limit for Spectrum 1          [1]
# 42            DSST Packed Waveform Data - Upper Dipole     [8, 512]
# 125   DSST Packed Waveform STC Filtered - Upper Dipole     [8, 512]
# 249         Packed Waveform Lower Limit for Spectrum 2          [1]
# 247  DSST Packed Waveform Spectrum Linear - Upper D...     [8, 256]
# 248  DSST Packed Waveform Spectrum Decibel - Upper ...     [8, 256]
# 250         Packed Waveform Upper Limit for Spectrum 2          [1]
# 45       DSST Packed Waveform Data - Monopole Stoneley     [1, 512]
# 145  DSST Packed Waveform STC Filtered - Monopole S...     [8, 512]
# 253         Packed Waveform Lower Limit for Spectrum 3          [1]
# 251    DSST Packed Waveform Spectrum Linear - Stoneley     [8, 256]
# 252   DSST Packed Waveform Spectrum Decibel - Stoneley     [8, 256]
# 254         Packed Waveform Upper Limit for Spectrum 3          [1]
# 48            DSST Packed Waveform Data - Monopole P&S     [8, 512]
# 158   DSST Packed Waveform STC Filtered - Monopole P&S     [8, 512]
# 257         Packed Waveform Lower Limit for Spectrum 4          [1]
# 255         DSST Packed Waveform Spectrum Linear - P&S     [8, 256]
# 256        DSST Packed Waveform Spectrum Decibel - P&S     [8, 256]
# 258         Packed Waveform Upper Limit for Spectrum 4          [1]
# 27                  DSST Packed Waveform Data - Expert  [1, 1, 512]
# 241         Packed Waveform Lower Limit for Spectrum X          [1]
# 239      DSST Packed Waveform Spectrum Linear - Expert          [0]
# 240     DSST Packed Waveform Spectrum Decibel - Expert          [0]
# 242         Packed Waveform Upper Limit for Spectrum X          [1]
# 41   DSST Packed Waveform Normalization Factors - L...          [1]
# 44   DSST Packed Waveform Normalization Factors - U...          [8]
# 47   DSST Packed Waveform Normalization Factors - M...          [1]
# 50   DSST Packed Waveform Normalization Factors - M...          [8]
# 29   DSST Packed Waveform Normalization Factors - E...       [1, 1]
# 291                                 DIP QUALITY FACTOR          [1]
# 17                                    Relative Bearing          [1]
# 100               Relative Bearing at DSST Tool Bottom          [1]
# 103                 Relative Bearing at Waveform Depth          [1]
# 460                                   Relative Bearing          [1]
# 444                                      Raw Gamma Ray          [1]
# 449                                 HiRes Raw GammaRay          [1]
# 106   STC Peak Slowness, Receiver Array - Lower Dipole         [16]
# 139  STC Peak Slowness, Receiver Array - Monopole S...         [16]
# 117  STC Peak Slowness, Transmitter Array - Lower D...         [16]
# 129  STC Peak Slowness, Transmitter Array - Upper D...         [16]
# 150  STC Peak Slowness, Transmitter Array - Monopol...         [16]
# 161              STC Sonic Array Status - Lower Dipole          [1]
# 162              STC Sonic Array Status - Upper Dipole          [1]
# 163         STC Sonic Array Status - Monopole Stoneley          [1]
# 164              STC Sonic Array Status - Monopole P&S          [1]
# 418                          CALIBRATED SPEED BUTTON 1          [1]
# 383                          CALIBRATED SPEED BUTTON 1          [1]
# 388                          CALIBRATED SPEED BUTTON 2          [1]
# 413                          CALIBRATED SPEED BUTTON 2          [1]
# 315                              Speed Corrected Depth          [1]
# 18                                     Sonde Deviation          [1]
# 461                                    Sonde Deviation          [1]
# 227                              Surelock Status - FMD          [1]
# 114  STC Signal/Noise Ratio, Receiver Array - Lower...          [1]
# 147  STC Signal/Noise Ratio, Receiver Array - Monop...          [1]
# 124  STC Signal/Noise Ratio, Transmitter Array - Lo...          [1]
# 136  STC Signal/Noise Ratio, Transmitter Array - Up...          [1]
# 157  STC Signal/Noise Ratio, Transmitter Array - Mo...          [1]
# 165     Borehole Size for Labeling and Bias Correction          [1]
# 286                            SPEED CORRECTION FACTOR          [1]
# 68                                      Sonic Porosity          [1]
# 113  STC Slowness Projection, Receiver Array - Lowe...        [176]
# 126  STC Slowness Projection, Receiver Array - Uppe...        [176]
# 146  STC Slowness Projection, Receiver Array - Mono...        [151]
# 159  STC Slowness Projection, Receiver Array - Mono...        [101]
# 123  STC Slowness Projection, Transmitter Array - L...        [176]
# 135  STC Slowness Projection, Transmitter Array - U...        [176]
# 156  STC Slowness Projection, Transmitter Array - M...        [151]
# 160  STC Slowness Projection, Transmitter Array - M...        [101]
# 75                                Sonic Shear Velocity          [1]
# 445                                    SGT Tool Status          [1]
# 74                                      Sonic Velocity          [1]
# 107       STC Peak Time, Receiver Array - Lower Dipole         [16]
# 140  STC Peak Time, Receiver Array - Monopole Stoneley         [16]
# 118    STC Peak Time, Transmitter Array - Lower Dipole         [16]
# 130    STC Peak Time, Transmitter Array - Upper Dipole         [16]
# 151  STC Peak Time, Transmitter Array - Monopole St...         [16]
# 110  STC Energy Peak Time, Receiver Array - Lower D...         [16]
# 143  STC Energy Peak Time, Receiver Array - Monopol...         [16]
# 121  STC Energy Peak Time, Transmitter Array - Lowe...         [16]
# 133  STC Energy Peak Time, Transmitter Array - Uppe...         [16]
# 154  STC Energy Peak Time, Transmitter Array - Mono...         [16]
# 478                Tool Check Second River Depth Index          [1]
# 471                     GPIT 300.msec Time River Depth          [1]
# 463                      GPIT 75.msec Time River Depth          [1]
# 454               Inclinometry Station Log River Depth          [1]
# 419                         1.5 Inch River Depth Index          [1]
# 447                      HiRes Depth River Depth Index          [1]
# 442                                  SGT-L River Depth          [1]
# 433                               0.1 inch River Depth          [1]
# 425                               1.5 inch River Depth          [1]
# 451                             STEP RIVER DEPTH INDEX          [1]
# 316                         0.1 Inch River Depth Index          [1]
# 0                                   6-Inch Frame Depth          [1]
# 309                                 2-Inch Frame Depth          [1]
# 312                                 1-Inch Frame Depth          [1]
# 26                       Computed Borehole Temperature          [1]
# 5                                        Cable Tension          [1]
# 172  Label Energy Peak Time, Receiver Array - Lower...          [1]
# 198  Label Energy Peak Time, Receiver Array - Monop...          [1]
# 180  Label Energy Peak Time, Transmitter Array - Lo...          [1]
# 190  Label Energy Peak Time, Transmitter Array - Up...          [1]
# 206  Label Energy Peak Time, Transmitter Array - Mo...          [1]
# 443                                   SGT-L River Time          [1]
# 420                          1.5 Inch River Time Index          [1]
# 313                                  1-Inch Frame Time          [1]
# 477                 Tool Check Second River Time Index          [1]
# 310                                  2-Inch Frame Time          [1]
# 317                          0.1 Inch River Time Index          [1]
# 470                      GPIT 300.msec Time River Time          [1]
# 434                                0.1 inch River Time          [1]
# 1                                    6-Inch Frame Time          [1]
# 462                       GPIT 75.msec Time River Time          [1]
# 453                Inclinometry Station Log River Time          [1]
# 452                              STEP RIVER TIME INDEX          [1]
# 426                                1.5 inch River Time          [1]
# 448                       HiRes Depth River Time Index          [1]
# 177     Label Peak Time, Receiver Array - Lower Dipole          [1]
# 203  Label Peak Time, Receiver Array - Monopole Sto...          [1]
# 185  Label Peak Time, Transmitter Array - Lower Dipole          [1]
# ...
# 77                                     Waveform Gain X          [1]
# 76                                          Waveform X        [512]
# 262                Waveform Lower Limit for Spectrum X          [1]
# 260             DSST Waveform Spectrum Linear - Expert        [255]
# 261            DSST Waveform Spectrum Decibel - Expert        [255]
# 263                Waveform Upper Limit for Spectrum X          [1]
#
#             Units       Frame
# 303            m2  Frame(60B)
# 302            m2  Frame(60B)
# 12           m/s2  Frame(60B)
# 455          m/s2        None
# 301            m2  Frame(60B)
# 427          m/s2  Frame(15B)
# 464          m/s2        None
# 428          m/s2  Frame(15B)
# 465          m/s2        None
# 429          m/s2  Frame(15B)
# 440          m/s2   Frame(1B)
# 441          m/s2   Frame(1B)
# 439                 Frame(1B)
# 98            deg        None
# 101           deg        None
# 466          m/s2        None
# 336                 Frame(1B)
# 337                 Frame(1B)
# 325                 Frame(1B)
# 338                 Frame(1B)
# 339                 Frame(1B)
# 340                 Frame(1B)
# 320                 Frame(1B)
# 341                 Frame(1B)
# 342                 Frame(1B)
# 329                 Frame(1B)
# 330                 Frame(1B)
# 331                 Frame(1B)
# 333                 Frame(1B)
# 334                 Frame(1B)
# 335                 Frame(1B)
# 319                 Frame(1B)
# 363                 Frame(1B)
# 364                 Frame(1B)
# 326                 Frame(1B)
# 365                 Frame(1B)
# 366                 Frame(1B)
# 367                 Frame(1B)
# 321                 Frame(1B)
# 368                 Frame(1B)
# 369                 Frame(1B)
# 356                 Frame(1B)
# 357                 Frame(1B)
# 358                 Frame(1B)
# 360                 Frame(1B)
# 361                 Frame(1B)
# 362                 Frame(1B)
# 324                 Frame(1B)
# 343                 Frame(1B)
# 344                 Frame(1B)
# 322                 Frame(1B)
# 345                 Frame(1B)
# 346                 Frame(1B)
# 347                 Frame(1B)
# 327                 Frame(1B)
# 348                 Frame(1B)
# 349                 Frame(1B)
# 350                 Frame(1B)
# 351                 Frame(1B)
# 352                 Frame(1B)
# 353                 Frame(1B)
# 354                 Frame(1B)
# 355                 Frame(1B)
# 332                 Frame(1B)
# 370                 Frame(1B)
# 371                 Frame(1B)
# 323                 Frame(1B)
# 372                 Frame(1B)
# 373                 Frame(1B)
# 374                 Frame(1B)
# 328                 Frame(1B)
# 375                 Frame(1B)
# 376                 Frame(1B)
# 377                 Frame(1B)
# 378                 Frame(1B)
# 379                 Frame(1B)
# 380                 Frame(1B)
# 381                 Frame(1B)
# 382                 Frame(1B)
# 359                 Frame(1B)
# 24            kPa        None
# 23          ohm.m        None
# 71                       None
# 72                       None
# 2              in  Frame(60B)
# 421            in  Frame(15B)
# 105                      None
# 138                      None
# 116                      None
# 128                      None
# 149                      None
# 422            in  Frame(15B)
# 109                      None
# 142                      None
# 120                      None
# 132                      None
# 153                      None
# 69             mV        None
# 285             N  Frame(60B)
# 173                      None
# 199                      None
# 181                      None
# 191                      None
# 207                      None
# 170                      None
# 186                Frame(60B)
# 196                      None
# 229                      None
# 213                Frame(60B)
# 215                Frame(60B)
# 178                      None
# 188                      None
# 204                      None
# 231                      None
# 217                Frame(60B)
# 219                Frame(60B)
# 295             m  Frame(60B)
# 3            ft/h  Frame(60B)
# 4           m/min  Frame(60B)
# 296         deg/m  Frame(60B)
# 384                 Frame(1B)
# 417                      None
# 416                      None
# 389                 Frame(1B)
# 415                      None
# 385                 Frame(1B)
# 414                      None
# 390                 Frame(1B)
# 391                 Frame(1B)
# 412                      None
# 411                      None
# 386                 Frame(1B)
# 392                 Frame(1B)
# 410                      None
# 409                      None
# 387                 Frame(1B)
# 304            in        None
# 61             in        None
# 62             in        None
# 60           dB/m        None
# 63             mV        None
# 64             mV        None
# 65   1000 kPa.s/m        None
# 66              %        None
# 93                       None
# 94                 Frame(60B)
# 95                       None
# 96                 Frame(60B)
# 97                       None
# 92                       None
# 294           deg  Frame(60B)
# 293           deg  Frame(60B)
# 8             deg  Frame(60B)
# 284             N  Frame(60B)
# 290           deg  Frame(60B)
# 289           deg  Frame(60B)
# 479                      None
# 480            dB        None
# 482                      None
# 483                      None
# 481                      None
# 220         us/ft        None
# 176         us/ft        None
# 184         us/ft        None
# 221         us/ft  Frame(60B)
# 187         us/ft  Frame(60B)
# 194         us/ft        None
# 202         us/ft        None
# 210         us/ft        None
# 223         us/ft  Frame(60B)
# 224         us/ft  Frame(60B)
# 225         us/ft        None
# 230         us/ft        None
# 232         us/ft        None
# 166         us/ft  Frame(60B)
# 212         us/ft  Frame(60B)
# 214         us/ft  Frame(60B)
# 167         us/ft  Frame(60B)
# 222         us/ft        None
# 216         us/ft  Frame(60B)
# 218         us/ft  Frame(60B)
# 99            deg        None
# 102           deg        None
# 108            dB        None
# 141            dB        None
# 119            dB        None
# 131            dB        None
# 152            dB        None
# 111            dB        None
# 144            dB        None
# 122            dB        None
# 134            dB        None
# 155            dB        None
# 21           gAPI  Frame(60B)
# 297             m  Frame(60B)
# 175            dB        None
# 201            dB        None
# 183            dB        None
# 193            dB        None
# 209            dB        None
# 311          gAPI        None
# 423            mA  Frame(15B)
# 171            dB        None
# 197            dB        None
# 179            dB        None
# 189            dB        None
# 205            dB        None
# 6               s  Frame(60B)
# 318             V   Frame(1B)
# 435          m/s2   Frame(1B)
# 436          m/s2   Frame(1B)
# 437          m/s2   Frame(1B)
# 305            in  Frame(60B)
# 14            deg  Frame(60B)
# 457           deg        None
# 13            A/m  Frame(60B)
# 456           A/m        None
# 226                      None
# 238            us        None
# 438            ms   Frame(1B)
# 237            us        None
# 430           A/m  Frame(15B)
# 467           A/m        None
# 431           A/m  Frame(15B)
# 468           A/m        None
# 432           A/m  Frame(15B)
# 469           A/m        None
# 472             V        None
# 19           degC  Frame(60B)
# 475          degC        None
# 22             in        None
# 20           degC  Frame(60B)
# 476          degC        None
# 474             V        None
# 70             mV        None
# 473             V        None
# 446          gAPI  Frame(60B)
# 25           degC        None
# 15            deg  Frame(60B)
# 458           deg        None
# 306            in  Frame(60B)
# 450          gAPI        None
# 308            m3  Frame(60B)
# 314        0.1 in  Frame(10B)
# 307            m3  Frame(60B)
# 67              s  Frame(60B)
# 174                      None
# 200                      None
# 182                      None
# 192                      None
# 208                      None
# 7               m        None
# 264            Hz        None
# 269            Hz        None
# 274            Hz        None
# 279            Hz        None
# 259            Hz        None
# 233         us/ft        None
# 234         us/ft        None
# 236         us/ft        None
# 235                      None
# 10                 Frame(60B)
# 11                 Frame(60B)
# 298             m  Frame(60B)
# 104                      None
# 137                      None
# 115                      None
# 127                      None
# 148                      None
# 16            deg  Frame(60B)
# 9             deg  Frame(60B)
# 459           deg        None
# 53                       None
# 32                       None
# 54              m        None
# 33              m        None
# 55                       None
# 34                       None
# 51                       None
# 30                       None
# 52                       None
# 31                       None
# 168                Frame(60B)
# 57                       None
# 36                       None
# 58              m        None
# 37              m        None
# 59                       None
# 38                       None
# 228            us        None
# 56             us        None
# 35             us        None
# 40              m        None
# 43              m        None
# 46              m        None
# 49              m        None
# 28              m        None
# 39                       None
# 112                      None
# 245            us        None
# 243                      None
# 244            dB        None
# 246            us        None
# 42                 Frame(60B)
# 125                      None
# 249            us        None
# 247                      None
# 248            dB        None
# 250            us        None
# 45                       None
# 145                      None
# 253            us        None
# 251                      None
# 252            dB        None
# 254            us        None
# 48                 Frame(60B)
# 158                      None
# 257            us        None
# 255                      None
# 256            dB        None
# 258            us        None
# 27                       None
# 241            us        None
# 239                      None
# 240            dB        None
# 242            us        None
# 41                       None
# 44                 Frame(60B)
# 47                       None
# 50                 Frame(60B)
# 29                       None
# 291                Frame(60B)
# 17            deg  Frame(60B)
# 100           deg        None
# 103           deg        None
# 460           deg        None
# 444          gAPI  Frame(60B)
# 449          gAPI        None
# 106         us/ft        None
# 139         us/ft        None
# 117         us/ft        None
# 129         us/ft        None
# 150         us/ft        None
# 161                      None
# 162                Frame(60B)
# 163                      None
# 164                Frame(60B)
# 418                      None
# 383                 Frame(1B)
# 388                 Frame(1B)
# 413                      None
# 315        0.1 in  Frame(10B)
# 18            deg  Frame(60B)
# 461           deg        None
# 227                      None
# 114            dB        None
# 147            dB        None
# 124            dB        None
# 136            dB        None
# 157            dB        None
# 165            in  Frame(60B)
# 286                Frame(60B)
# 68          m3/m3  Frame(60B)
# 113                      None
# 126                Frame(60B)
# 146                      None
# 159                Frame(60B)
# 123                      None
# 135                      None
# 156                      None
# 160                Frame(60B)
# 75            m/s  Frame(60B)
# 445                      None
# 74            m/s  Frame(60B)
# 107            us        None
# 140            us        None
# 118            us        None
# 130            us        None
# 151            us        None
# 110            us        None
# 143            us        None
# 121            us        None
# 133            us        None
# 154            us        None
# 478        0.1 in        None
# 471        0.1 in        None
# 463        0.1 in        None
# 454        0.1 in        None
# 419        0.1 in  Frame(15B)
# 447        0.1 in        None
# 442        0.1 in        None
# 433        0.1 in        None
# 425        0.1 in        None
# 451        0.1 in        None
# 316        0.1 in   Frame(1B)
# 0          0.1 in  Frame(60B)
# 309        0.1 in        None
# 312        0.1 in  Frame(10B)
# 26           degC        None
# 5             lbf  Frame(60B)
# 172            us        None
# 198            us        None
# 180            us        None
# 190            us        None
# 206            us        None
# 443            ms        None
# 420            ms  Frame(15B)
# 313            ms  Frame(10B)
# 477            ms        None
# 310            ms        None
# 317            ms   Frame(1B)
# 470            ms        None
# 434            ms        None
# 1              ms  Frame(60B)
# 462            ms        None
# 453            ms        None
# 452            ms        None
# 426            ms        None
# 448            ms        None
# 177            us        None
# 203            us        None
# 185            us        None
# 195            us        None
# 211            us        None
# 299             m  Frame(60B)
# 288                      None
# 287           deg        None
# 292           deg        None
# 424                Frame(15B)
# 401                      None
# 402                      None
# 403                      None
# 404                      None
# 405                      None
# 406                      None
# 407                      None
# 408                      None
# 393                      None
# 397                      None
# 394                      None
# 398                      None
# 395                      None
# 399                      None
# 396                      None
# 400                      None
# 73                       None
# 169                Frame(60B)
# 300             m  Frame(60B)
# 81                       None
# 84                       None
# 87                       None
# 90                       None
# 91                       None
# 78                       None
# 79                       None
# 267            us        None
# 265                      None
# 266            dB        None
# 268            us        None
# 82                       None
# 272            us        None
# 270                      None
# 271            dB        None
# 273            us        None
# 85                       None
# 277            us        None
# 275                      None
# 276            dB        None
# 278            us        None
# 88                       None
# 282            us        None
# 280                      None
# 281            dB        None
# 283            us        None
# 80                       None
# 83                       None
# 86                       None
# 89                       None
# 77                       None
# 76                       None
# 262            us        None
# 260                      None
# 261            dB        None
# 263            us        None

# %% [markdown]
# ### Tools
# The tools object within the DLIS file contains information relating to the tools that were used to acquire the data. We can get a summary of the tools available be calling upon the `summary_dataframe` method.

# %%
tools = summary_dataframe(f.tools, name='Name', description='Description')
tools
# Out:
#     Name                          Description
# 3  DSSTB              Dipole Shear Imager - B
# 2   DTAA         Downhole Toolbus Adapter - A
# 4   DTCA              DTS Telemetry Cartridge
# 0  MESTB  Micro Electrical Scanner - B (Slim)
# 1   SGTL          Scintillation Gamma-Ray - L

# %% [markdown]
# As we are looking to plot acoustic waveform data, we can look at the parameters for the DSSTB - Dipole Shear Imager tool. First, we need to grab the object from the dlis and then pass it into the `summary_dataframe` function.
#
# From the returned table, we can view each of the parameters that relate to the tool and the processing of the data.

# %%
dsstb = f.object('TOOL', 'DSSTB')
dsstb_params = summary_dataframe(dsstb.parameters, name='Name', long_name='Long Name', values='Values')
dsstb_params
# Out:
#           Name                                          Long Name  \
# 33   BARS_MTR1      Length for Monopole Transmitter to Receiver 1
# 6          BHS                                    Borehole Status
# 1          BHT     Bottom Hole Temperature (used in calculations)
# 18        BILI                Bond Index Level for Zone Isolation
# 213       CASF               Label Casing Function - Monopole P&S
# 10        CDTS                                    C-Delta-T Shale
# 206       COLL  Label Slowness Lower Limit - Monopole P&S Comp...
# 207       COUL  Label Slowness Upper Limit - Monopole P&S Comp...
# 17        CSTR                     Compressive Strength of Cement
# 114       DCL1                  STC DC Lower Limit - Lower Dipole
# 134       DCL2                  STC DC Lower Limit - Upper Dipole
# 154       DCL3             STC DC Lower Limit - Monopole Stoneley
# 174       DCL4                  STC DC Lower Limit - Monopole P&S
# 116       DCM1                      STC DC Moveout - Lower Dipole
# 136       DCM2                      STC DC Moveout - Upper Dipole
# 156       DCM3                 STC DC Moveout - Monopole Stoneley
# 176       DCM4                      STC DC Moveout - Monopole P&S
# 115       DCU1                  STC DC Upper Limit - Lower Dipole
# 135       DCU2                  STC DC Upper Limit - Upper Dipole
# 155       DCU3             STC DC Upper Limit - Monopole Stoneley
# 175       DCU4                  STC DC Upper Limit - Monopole P&S
# 48        DDE1                                 Digitizing Delay 1
# 56        DDE2                                 Digitizing Delay 2
# 64        DDE3                                 Digitizing Delay 3
# 72        DDE4                                 Digitizing Delay 4
# 80        DDE5                                 Digitizing Delay 5
# 38        DDEX                                 Digitizing Delay X
# 190       DLCS          Label Compressional Source - Dipole Shear
# 185       DLHS        Label Hole Diameter Source for SOBS Channel
# 188       DSHL          Label Slowness Lower Limit - Dipole Shear
# 189       DSHU          Label Slowness Upper Limit - Dipole Shear
# 47        DSI1                        Digitizer Sample Interval 1
# 55        DSI2                        Digitizer Sample Interval 2
# 63        DSI3                        Digitizer Sample Interval 3
# 71        DSI4                        Digitizer Sample Interval 4
# 79        DSI5                        Digitizer Sample Interval 5
# 37        DSIX                        Digitizer Sample Interval X
# 186       DTCS      Compressional Delta-T Source for DTCO Channel
# 11         DTF                                      Delta-T Fluid
# 12         DTM                                     Delta-T Matrix
# 187       DTSS              Shear Delta-T Source for DTSM Channel
# 49        DWC1                             Digitizer Word Count 1
# 57        DWC2                             Digitizer Word Count 2
# 65        DWC3                             Digitizer Word Count 3
# 73        DWC4                             Digitizer Word Count 4
# 81        DWC5                             Digitizer Word Count 5
# 39        DWCX                             Digitizer Word Count X
# 13         FCF                      CBL Fluid Compensation Factor
# 87        FGM5                        First Motion Gate Moveout 5
# 212       FILG              Label Fill Gap Control - Monopole P&S
# 86        FMG5                        First Motion Minimum Gate 5
# 215       FMLL                         Slowness Lower Limit - FMD
# 218       FMRC                              Restart Control - FMD
# 85        FMT5                           First Motion Threshold 5
# 216       FMUL                         Slowness Upper Limit - FMD
# 220        FPM                              Processing Mode - FMD
# 0         FULT               FTB Uplink Throughput for Sonic Tool
# 2         GCSE                      Generalized Caliper Selection
# 9         GDEV  Average Angular Deviation of Borehole from Normal
# 52        GDT1                                     Gain Delta-T 1
# 60        GDT2                                     Gain Delta-T 2
# 68        GDT3                                     Gain Delta-T 3
# 76        GDT4                                     Gain Delta-T 4
# 84        GDT5                                     Gain Delta-T 5
# 42        GDTX                                     Gain Delta-T X
# 3         GGRD                                Geothermal Gradient
# 51        GIN1                                    Gain Interval 1
# 59        GIN2                                    Gain Interval 2
# 67        GIN3                                    Gain Interval 3
# 75        GIN4                                    Gain Interval 4
# 83        GIN5                                    Gain Interval 5
# 41        GINX                                    Gain Interval X
# 21        GOBO                                          Good Bond
# 5         GRSE              Generalized Mud Resistivity Selection
# 8         GTSE                  Generalized Temperature Selection
# 14        ITTS                     Integrated Transit Time Source
# 34        JNUM                                SPAC DHC ROM Number
# 214        LFC           Label Formation Character - Monopole P&S
# 181       LPM1               Label Processing Mode - Lower Dipole
# 182       LPM2               Label Processing Mode - Upper Dipole
# 183       LPM3          Label Processing Mode - Monopole Stoneley
# 184       LPM4               Label Processing Mode - Monopole P&S
# 22        LTXG                  Lower Dipole Transmitter Geometry
# 219       MAI5                  Slowness Averaging Interval - FMD
# 4         MATR       Rock Matrix for Neutron Porosity Corrections
# 20         MCI                          Minimum Cemented Interval
# 205        MCS                               Mean Casing Slowness
# 221       MDS5                    Multishot Delta-T Scatter - FMD
# 19         MSA                            Minimum Sonic Amplitude
# 24        MTXG                      Monopole Transmitter Geometry
# 50        NWS1                         Number Waveforms Stacked 1
# 58        NWS2                         Number Waveforms Stacked 2
# 66        NWS3                         Number Waveforms Stacked 3
# 74        NWS4                         Number Waveforms Stacked 4
# 82        NWS5                         Number Waveforms Stacked 5
# 40        NWSX                         Number Waveforms Stacked X
# 35        RATE                                        Firing Rate
# 210       RSMN  Label Shear/Compressional Minimum Ratio - Mono...
# 211       RSMX  Label Shear/Compressional Maximum Ratio - Mono...
# 25        RX1G                                Receiver 1 Geometry
# 26        RX2G                                Receiver 2 Geometry
# 27        RX3G                                Receiver 3 Geometry
# 28        RX4G                                Receiver 4 Geometry
# 29        RX5G                                Receiver 5 Geometry
# 30        RX6G                                Receiver 6 Geometry
# 31        RX7G                                Receiver 7 Geometry
# 32        RX8G                                Receiver 8 Geometry
# 46        SAM1  DSST Sonic Acquisition Mode 1 - Lower Dipole Mode
# 54        SAM2  DSST Sonic Acquisition Mode 2 - Upper Dipole Mode
# 62        SAM3  DSST Sonic Acquisition Mode 3 - Low Frequency ...
# 70        SAM4  DSST Sonic Acquisition Mode 4 - High Frequency...
# 78        SAM5  DSST Sonic Acquisition Mode 5 - High Frequency...
# 36        SAMX  DSST Sonic Acquisition Mode X - Both Dipoles o...
# 103       SAS1              STC Sonic Array Status - Lower Dipole
# 123       SAS2              STC Sonic Array Status - Upper Dipole
# 143       SAS3         STC Sonic Array Status - Monopole Stoneley
# 163       SAS4              STC Sonic Array Status - Monopole P&S
# 217       SAS5                           Sonic Array Status - FMD
# 106       SBO1              STC Search Band Offset - Lower Dipole
# 126       SBO2              STC Search Band Offset - Upper Dipole
# 146       SBO3         STC Search Band Offset - Monopole Stoneley
# 166       SBO4              STC Search Band Offset - Monopole P&S
# 180       SBR4                STC Baseline Removal - Monopole P&S
# 105       SBW1                STC Search Bandwidth - Lower Dipole
# 125       SBW2                STC Search Bandwidth - Upper Dipole
# 145       SBW3           STC Search Bandwidth - Monopole Stoneley
# 165       SBW4                STC Search Bandwidth - Monopole P&S
# 102       SFC1             STC Formation Character - Lower Dipole
# 122       SFC2             STC Formation Character - Upper Dipole
# 142       SFC3        STC Formation Character - Monopole Stoneley
# 162       SFC4             STC Formation Character - Monopole P&S
# 104       SFM1                          STC Filter - Lower Dipole
# 124       SFM2                          STC Filter - Upper Dipole
# 144       SFM3                     STC Filter - Monopole Stoneley
# 164       SFM4                          STC Filter - Monopole P&S
# 117       SGL1              STC Signal Lower Limit - Lower Dipole
# 137       SGL2              STC Signal Lower Limit - Upper Dipole
# 157       SGL3         STC Signal Lower Limit - Monopole Stoneley
# 177       SGL4              STC Signal Lower Limit - Monopole P&S
# 119       SGM1                  STC Signal Moveout - Lower Dipole
# 139       SGM2                  STC Signal Moveout - Upper Dipole
# 159       SGM3             STC Signal Moveout - Monopole Stoneley
# 179       SGM4                  STC Signal Moveout - Monopole P&S
# 118       SGU1              STC Signal Upper Limit - Lower Dipole
# 138       SGU2              STC Signal Upper Limit - Upper Dipole
# 158       SGU3         STC Signal Upper Limit - Monopole Stoneley
# 178       SGU4              STC Signal Upper Limit - Monopole P&S
# 208       SHLL    Label Slowness Lower Limit - Monopole P&S Shear
# 7          SHT                           Surface Hole Temperature
# 209       SHUL    Label Slowness Upper Limit - Monopole P&S Shear
# 100       SLL1            STC Slowness Lower Limit - Lower Dipole
# 120       SLL2            STC Slowness Lower Limit - Upper Dipole
# 140       SLL3       STC Slowness Lower Limit - Monopole Stoneley
# 160       SLL4            STC Slowness Lower Limit - Monopole P&S
# 15        SPFS                             Sonic Porosity Formula
# 93        SPM1                 STC Processing Mode - Lower Dipole
# 94        SPM2                 STC Processing Mode - Upper Dipole
# 95        SPM3            STC Processing Mode - Monopole Stoneley
# 96        SPM4                 STC Processing Mode - Monopole P&S
# 16        SPSO                              Sonic Porosity Source
# 111       SST1                   STC Slowness Step - Lower Dipole
# 131       SST2                   STC Slowness Step - Upper Dipole
# 151       SST3              STC Slowness Step - Monopole Stoneley
# 171       SST4                   STC Slowness Step - Monopole P&S
# 97        SSW1                 STC Source Waveform - Lower Dipole
# 98        SSW2                 STC Source Waveform - Upper Dipole
# 99        SSW4                 STC Source Waveform - Monopole P&S
# 197       STLL     Label Slowness Lower Limit - Monopole Stoneley
# 198       STUL     Label Slowness Upper Limit - Monopole Stoneley
# 101       SUL1            STC Slowness Upper Limit - Lower Dipole
# 121       SUL2            STC Slowness Upper Limit - Upper Dipole
# 141       SUL3       STC Slowness Upper Limit - Monopole Stoneley
# 161       SUL4            STC Slowness Upper Limit - Monopole P&S
# 113       SWD1                  STC Slowness Width - Lower Dipole
# 133       SWD2                  STC Slowness Width - Upper Dipole
# 153       SWD3             STC Slowness Width - Monopole Stoneley
# 173       SWD4                  STC Slowness Width - Monopole P&S
# 89        TBF1          STC Time for Baseline Fill - Lower Dipole
# 90        TBF2          STC Time for Baseline Fill - Upper Dipole
# 91        TBF3     STC Time for Baseline Fill - Monopole Stoneley
# 92        TBF4          STC Time for Baseline Fill - Monopole P&S
# 196       THSH               Label Spike Threshold - Dipole Shear
# 204       THST          Label Spike Threshold - Monopole Stoneley
# 107       TLL1                STC Time Lower Limit - Lower Dipole
# 127       TLL2                STC Time Lower Limit - Upper Dipole
# 147       TLL3           STC Time Lower Limit - Monopole Stoneley
# 167       TLL4                STC Time Lower Limit - Monopole P&S
# 109       TST1                       STC Time Step - Lower Dipole
# 129       TST2                       STC Time Step - Upper Dipole
# 149       TST3                  STC Time Step - Monopole Stoneley
# 169       TST4                       STC Time Step - Monopole P&S
# 108       TUL1                STC Time Upper Limit - Lower Dipole
# 128       TUL2                STC Time Upper Limit - Upper Dipole
# 148       TUL3           STC Time Upper Limit - Monopole Stoneley
# 168       TUL4                STC Time Upper Limit - Monopole P&S
# 112       TWD1                      STC Time Width - Lower Dipole
# 132       TWD2                      STC Time Width - Upper Dipole
# 152       TWD3                 STC Time Width - Monopole Stoneley
# 172       TWD4                      STC Time Width - Monopole P&S
# 110       TWI1         STC Integration Time Window - Lower Dipole
# 130       TWI2         STC Integration Time Window - Upper Dipole
# 150       TWI3    STC Integration Time Window - Monopole Stoneley
# 170       TWI4         STC Integration Time Window - Monopole P&S
# 43        TWRX                 Transmitter Waveform Sample Rate X
# 44        TWSX                      Transmitter Waveform Select X
# 23        UTXG                  Upper Dipole Transmitter Geometry
# 194       WASH            Label Early Arrival Cost - Dipole Shear
# 202       WAST       Label Early Arrival Cost - Monopole Stoneley
# 191       WCSH                Label Coherence Cost - Dipole Shear
# 199       WCST           Label Coherence Cost - Monopole Stoneley
# 195       WDSH            Label S/T Deviation Cost - Dipole Shear
# 203       WDST       Label S/T Deviation Cost - Monopole Stoneley
# 53        WFM1                                    Waveform Mode 1
# 61        WFM2                                    Waveform Mode 2
# 69        WFM3                                    Waveform Mode 3
# 77        WFM4                                    Waveform Mode 4
# 88        WFM5                                    Waveform Mode 5
# 45        WFMX                                    Waveform Mode X
# 192       WSSH                 Label Slowness Cost - Dipole Shear
# 200       WSST            Label Slowness Cost - Monopole Stoneley
# 193       WTSH                     Label Time Cost - Dipole Shear
# 201       WTST                Label Time Cost - Monopole Stoneley
#
#                      Values
# 33     [2.7432000637054443]
# 6                    [OPEN]
# 1                   [160.0]
# 18      [0.800000011920929]
# 213                  [50.0]
# 10                  [100.0]
# 206                  [40.0]
# 207                 [180.0]
# 17                    [0.0]
# 114                   [0.0]
# 134                   [0.0]
# 154                   [0.0]
# 174                   [0.0]
# 116                  [75.0]
# 136                  [75.0]
# 156                 [180.0]
# 176                  [40.0]
# 115                 [825.0]
# 135                 [825.0]
# 155                [1620.0]
# 175                 [360.0]
# 48                      [0]
# 56                      [0]
# 64                      [0]
# 72                      [0]
# 80                      [0]
# 38                      [0]
# 190                   [USE]
# 185                    [C1]
# 188                  [75.0]
# 189                 [775.0]
# 47                     [40]
# 55                     [40]
# 63                     [40]
# 71                     [10]
# 79                     [10]
# 37                     [40]
# 186               [PS_COMP]
# 11                  [189.0]
# 12                   [56.0]
# 187          [UPPER_DIPOLE]
# 49                    [512]
# 57                    [512]
# 65                    [512]
# 73                    [512]
# 81                    [512]
# 39                    [512]
# 13                    [1.0]
# 87                     [40]
# 212            [COMP_SHEAR]
# 86                    [500]
# 215                  [40.0]
# 218              [CONTINUE]
# 85                     [UP]
# 216                 [180.0]
# 220                  [NONE]
# 0                     [400]
# 2                      [C1]
# 9                     [0.0]
# 52                    [800]
# 60                    [800]
# 68                    [800]
# 76                    [160]
# 84                    [160]
# 42                    [800]
# 3    [0.018226999789476395]
# 51                  [15360]
# 59                  [15360]
# 67                  [15360]
# 75                   [2560]
# 83                   [1600]
# 41                  [15360]
# 21                    [2.0]
# 5                    [GEN9]
# 8                    [TEMP]
# 14                   [DTCO]
# 34                 [959250]
# 214            [COMP_FIRST]
# 181                  [NONE]
# 182              [RECEIVER]
# 183                  [NONE]
# 184                 [DDBHC]
# 22                    [156]
# 219                    [42]
# 4                    [LIME]
# 20     [3.0480000972747803]
# 205                  [57.0]
# 221                  [20.0]
# 19      [3.554243803024292]
# 24                    [186]
# 50                      [1]
# 58                      [1]
# 66                      [1]
# 74                      [1]
# 82                      [1]
# 40                      [1]
# 35                    [R15]
# 210     [1.399999976158142]
# 211     [2.119999885559082]
# 25                    [294]
# 26                    [300]
# 27                    [306]
# 28                    [312]
# 29                    [318]
# 30                    [324]
# 31                    [330]
# 32                    [336]
# 46                    [OFF]
# 54                    [ODD]
# 62                    [OFF]
# 70                   [EVEN]
# 78                    [OFF]
# 36                    [OFF]
# 103                   [255]
# 123                   [255]
# 143                   [255]
# 163                   [255]
# 217                   [255]
# 106                [3000.0]
# 126                [3000.0]
# 146                [3000.0]
# 166                 [500.0]
# 180                    [ON]
# 105                [8000.0]
# 125                [8000.0]
# 145                [8000.0]
# 165                [2000.0]
# 102            [SELECTABLE]
# 122            [SELECTABLE]
# 142            [SELECTABLE]
# 162            [SELECTABLE]
# 104                 [B1-3K]
# 124                 [B1-3K]
# 144              [B.5-1.5K]
# 164                [B3-20K]
# 117                 [825.0]
# 137                 [825.0]
# 157                [1620.0]
# 177                 [360.0]
# 119                  [75.0]
# 139                  [75.0]
# 159                 [180.0]
# 179                  [40.0]
# 118               [13525.0]
# 138               [15525.0]
# 158               [12020.0]
# 178                [3660.0]
# 208                  [75.0]
# 7                    [20.0]
# 209                 [180.0]
# 100                  [75.0]
# 120                  [75.0]
# 140                 [180.0]
# 160                  [40.0]
# 15                    [R-H]
# 93                   [NONE]
# 94               [RECEIVER]
# 95                   [NONE]
# 96                  [DDBHC]
# 16                   [DTCO]
# 111                   [4.0]
# 131                   [4.0]
# 151                   [4.0]
# 171                   [2.0]
# 97                [WF_SAM1]
# 98                [WF_SAM2]
# 99                [WF_SAM4]
# 197                 [180.0]
# 198                 [780.0]
# 101                 [775.0]
# 121                 [775.0]
# 141                 [780.0]
# 161                 [240.0]
# 113                  [40.0]
# 133                  [40.0]
# 153                  [40.0]
# 173                  [10.0]
# 89                      [0]
# 90                      [0]
# 91                      [0]
# 92                    [300]
# 196                  [15.0]
# 204                  [15.0]
# 107                 [600.0]
# 127                 [600.0]
# 147                 [600.0]
# 167                 [150.0]
# 109                 [200.0]
# 129                 [200.0]
# 149                 [200.0]
# 169                  [50.0]
# 108               [13525.0]
# 128               [15525.0]
# 148               [12000.0]
# 168                [3660.0]
# 112                [2000.0]
# 132                [2000.0]
# 152                [2000.0]
# 172                [1000.0]
# 110                [1600.0]
# 130                [1600.0]
# 150                [2400.0]
# 170                 [500.0]
# 43                      [5]
# 44                      [0]
# 23                    [162]
# 194                   [0.0]
# 202                   [0.0]
# 191                  [15.0]
# 199                   [5.0]
# 195                   [3.0]
# 203                   [3.0]
# 53                     [W1]
# 61                     [W1]
# 69                     [W1]
# 77                     [W1]
# 88                     [W1]
# 45                     [W1]
# 192                  [15.0]
# 200                  [15.0]
# 193                   [3.0]
# 201                   [3.0]

# %% [markdown]
# ## Working With Data Objects
# Now that some of the meta data has been explored, we can now attempt to access the data stored within the file.
#
# Frames and data can be accessed by calling upon the `.object()` for the file. First, we can assign the frames to variables, which will make things easier when accessing the data within them, especially if the frames contain channels/curves with the same name. The `.object()` method requires the type of the object being accessed, i.e. 'FRAME' or 'CHANNEL' and its name. In this case we can refer back to the previous step which contains the channels and the frame names. We can see that the basic logging curves are in one frame and the acoustic data is in another.

# %%
frame1 = f.object('FRAME','60B')

# %% [markdown]
# We can also directly access the channels for a specific curve. However, this can cause confusion when working with frames containing channels/curves with the same name.
#
# The example below shows how to call key properties of the channel/curve. Details of which can be found [here.](https://dlisio.readthedocs.io/en/stable/dlis/api.html#dlisio.dlis.Channel)

# %%
dtc = f.object('CHANNEL', 'PWF4')

# Print out the properties of the channel/curve
print(f'Name: \t\t{dtc.name}')
print(f'Long Name: \t{dtc.long_name}')
print(f'Units: \t\t{dtc.units}')
print(f'Dimension: \t{dtc.dimension}') #if >1, then data is an array
# Out:
# Name: 		PWF4
# Long Name: 	DSST Packed Waveform Data - Monopole P&S
# Units:
# Dimension: 	[8, 512]

# %% [markdown]
# ### Plotting Data
# Now that we know how to access the frames and channels of the DLIS file, we can now assign variable names to the curves that we are looking to plot. In this article, we will be plotting:
#
# - DTCO: Delta-T Compressional
# - DTSM: Delta-T Shear
# - SPR4: STC Slowness Projection, Receiver Array - Monopole P&S
# - PWF4: DSST Packed Waveform Data - Monopole P&S
#
# We will also need to assign a depth curve (TDEP) from the frame. Looking back at the information section of the frame, the `Depth Interval` is 0.1 inches. This needs to be converted to metres by multiplying by 0.00254.

# %%
curves = frame1.curves()

depth = curves['TDEP'] * 0.00254
dtco = curves['DTCO']
dtsm = curves['DTSM']
stc_mono = curves['SPR4']
wf_mono = curves['PWF4']

print(f'{depth.min()} - {depth.max()}')
# Out:
# 4574.4384765625 - 4819.04052734375

# %% [markdown]
# To make an initial check on data, we can create a quick log plot of DTCO and DTSM against depth using matplotlib.

# %%
plt.plot(depth, dtco)
plt.plot(depth, dtsm)
plt.ylim(40, 240)
# Out:
# (40.0, 240.0)

# %% [markdown]
# ### Plotting the Semblance Map
#
# We will start with setting up a subplot with two axes and using `subplot2grid`. The first axis will contain the semblance plot and the second will be twinned with the first. This allows the data to be plotted on the same y-axis.
#
# To plot the semblance data we need to use `imshow`. When we do this, we need to pass in the extent of the array both in terms of depth range (using `depth.min() and depth.max()`) and the data range (40 - 240 us/ft).
#
# On top of that, the DTCO and DTSM curves can be plotted. This allows us to see how these curves were picked from the semblance map.

# %%
fig, axes = plt.subplots(figsize=(7,10))

ax1 = plt.subplot2grid((1, 1), (0,0))
ax2 = ax1.twiny()

ax1.imshow(stc_mono, interpolation='bilinear', aspect='auto',
          cmap=plt.cm.jet, vmin=0, vmax=100,
           extent=[40, 240, depth.min(), depth.max()])

#Setting up the display depth range. Note that the
# depths need to be deepest first and shallowest second
ax1.set_ylim(depth.max(), depth.min())

ax2.plot(dtco, depth, color='black')
ax2.plot(dtsm, depth, color='brown')

ax2.set_xlim(40, 240)

plt.show()

# %% [markdown]
# ### Plotting the Processed Waveform Data
#
# We can modify the plot to add in a subplot for the acoustic waveform data associated with the semblance map. If we look at the shape of wf_mono we can see it returns (1606, 8, 512). This indicates that the array is multi-dimensional. The middle number indicates that we have 8 receivers worth of data.

# %%
wf_mono.shape
# Out:
# (1606, 8, 512)

# %% [markdown]
# To access the first receiver, which is usually the closest one to the transmitter array, we can create a slice of the data like so:

# %%
wf_r1 = wf_mono[:, 0, :]
print(wf_r1.min())
print(wf_r1.max())
# Out:
# -8192
# 8188

# %% [markdown]
# This code returns the minimum and maximum values of the array, which can be used as a guide for scaling colours.
#
# Taking the plot code from the semblance map section, we can enhance it by adding another subplot. In this subplot, we will use another `imshow()` plot and pass in the relevant parameters. The `vmin` and `vmax` parameters can be used to tweak the image to bring out or reduce the detail within the waveform.

# %%
fig = plt.subplots(figsize=(10,10))

# Subplot for the semblance map
ax1 = plt.subplot2grid((1, 2), (0,0))

# Subplot for the DTC and DTS curves
ax2 = ax1.twiny()

# Subplot for the waveform data
ax3 = plt.subplot2grid((1, 2), (0,1))

ax1.imshow(stc_mono, interpolation='bilinear', aspect='auto',
          cmap=plt.cm.jet, vmin=0, vmax=100,
           extent=[40, 240, depth.min(), depth.max()])

ax1.set_title('Monopole Semblance')

ax2.plot(dtco, depth, color='black')
ax2.set_xlim(40, 240)
ax2.set_xticks([])

ax2.plot(dtco, depth, color='black')
ax2.plot(dtsm, depth, color='brown')

ax3.set_title('Monopole Waveform R1')
ax3.imshow(wf_r1, interpolation='bilinear', aspect='auto',
          cmap=plt.cm.seismic, vmin=-2000, vmax=2000,
           extent=[0, 3000, depth.min(), depth.max()])

ax3.set_xlim(0, 1000)


for ax in [ax1, ax2, ax3]:
    ax.set_ylim(depth.max(), depth.min())

# %% [markdown]
# ### Adding Interactive Controls
#
# Rather than rerunning the cell each time the depth and/or DT plot scales require changing, we can add a few interactive widgets to help with this. This can be achieved by importing `ipywidgets` and `IPython.display`.
# The plot code can be placed inside a function and decorated with the widgets code. In the example below, we are passing in MinDepth, MaxDepth, MinDT and MaxDT. All four of which can be called upon in the code.

# %%
import ipywidgets as widgets
from IPython.display import display

# Add the widgets decorator and setup the interactive variables
@widgets.interact(MinDepth=(depth.min(),depth.max(), 10), 
                  MaxDepth=(depth.min(),depth.max(), 10),
                 MinDT=(40, 240, 5),
                 MaxDT=(40, 240, 5))
def acoustic_plot(MinDepth=depth.min(), MaxDepth=depth.max(),
                 MinDT=40, MaxDT=240):
    fig = plt.subplots(figsize=(10,10))

    # Subplot for the semblance map
    ax1 = plt.subplot2grid((1, 2), (0,0))

    # Subplot for the DTC and DTS curves
    ax2 = ax1.twiny()

    # Subplot for the waveform data
    ax3 = plt.subplot2grid((1, 2), (0,1))

    ax1.imshow(stc_mono, interpolation='bilinear', aspect='auto',
              cmap=plt.cm.jet, vmin=0, vmax=100,
               extent=[40, 240, depth.min(), depth.max()])
    ax1.set_xlim(MinDT, MaxDT)
    ax1.set_title('Monopole Semblance')

    ax2.plot(dtco, depth, color='black')
    ax2.set_xlim(MinDT, MaxDT)
    ax2.set_xticks([])

    ax2.plot(dtco, depth, color='black')
    ax2.plot(dtsm, depth, color='brown')

    ax3.set_title('Monopole Waveform R1')
    ax3.imshow(wf_r1, interpolation='bilinear', aspect='auto',
              cmap=plt.cm.seismic, vmin=-2000, vmax=2000,
               extent=[0, 3000, depth.min(), depth.max()])

    ax3.set_xlim(0, 1000)


    for ax in [ax1, ax2, ax3]:
        ax.set_ylim(MaxDepth, MinDepth)
# Out:
# interactive(children=(FloatSlider(value=4574.4384765625, description='MinDepth', max=4819.04052734375, min=457…

# %% [markdown]
# ## Summary
# In this article, we have covered how to load a DLIS file using the DLISIO Python library. Once the DLIS file is loaded, different parameter tables and logging curves can be viewed and extracted. We have also seen how we can take processed acoustic waveform data and plot it using matplotlib. DLIS files don't have to be daunting to work with in Python. Once the basic structure and commands from DLISIO are understood it becomes much simpler.

# %% [markdown]
# ***Thanks for reading!***
#
# *If you have found this article useful, please feel free to check out my other articles looking at various aspects of Python and well log data. You can also find my code used in this article and others at [GitHub](https://github.com/andymcdgeo).*
#
# *If you want to get in touch you can find me on [LinkedIn](https://www.linkedin.com/in/andymcdonaldgeo/) or at my [website](http://andymcdonald.scot/).*
#
# *Interested in learning more about python and well log data or petrophysics? Follow me on [Medium](https://medium.com/@andymcdonaldgeo).*

# %% [markdown]
# ## References

# %% [markdown]
# [Viggen, E.M. Extracing data from DLIS Files](https://erlend-viggen.no/dlis-files/)
# [Viggen, E.M, Harstad, E., and Kvalsvik J. (2020), Getting started with acoustic well log data using the dlisio Python library on the Volve Data Village dataset](https://www.researchgate.net/publication/340645995_Getting_started_with_acoustic_well_log_data_using_the_dlisio_Python_library_on_the_Volve_Data_Village_dataset)
#
# [NLOG: Dutch Oil and Gas Portal](https://www.nlog.nl/en/welcome-nlog)
